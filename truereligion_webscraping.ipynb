# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import requests
import re
import math

from bs4 import BeautifulSoup
from datetime import datetime

# %% [markdown]
# # Data Collection (products)

# %%
# URL
url01 = "https://www.macys.com/shop/mens-clothing/mens-jeans/Productsperpage/120?id=11221"

# %%
# Parameters
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Request to URL
page = requests.get(url01, headers=headers)

# Beautiful Soup object
soup = BeautifulSoup(page.text, 'html.parser')

# %%
print(page.text)
# Out:
# <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access the requested URL on this server.
# <P>Reference: 18.13c81002.1669899994.ffc1823c</P>
# </BODY>
# </HTML>

# %%
soup
# Out:
# <html><head>
# <title>Access Denied</title>
# </head><body>
# <h1>Access Denied</h1>
#
# You don't have permission to access the requested URL on this server.
# <p>Reference: 18.13c81002.1669899994.ffc1823c</p>
# </body>
# </html>

# %%
# List which contains all products
products = soup.find('div', 'mainContainer').find_all('div')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <cell line: 2>()
#       1 # List which contains all products
# ----> 2 products = soup.find('div', 'results-grid -show').find_all('div')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
print( products )
# Out:
# None

# %%
# List which contains all products
products = soup.find('div', 'grid-x sticky-header-observer')

# %%
print(products)
# Out:
# None

# %%
# product_name list
product_name = products.find_all('div', 'product-name')

# %%
product_name
# Out:
# []

# %%
# URL
url01 = "https://www.levi.com/US/en_US/clothing/men/jeans/c/levi_clothing_men_jeans"

# Parameters
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Request to URL
page = requests.get(url01, headers=headers)

# Beautiful Soup object
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html><head><meta charset="utf-8"/><meta content="text/html; charset=utf-8" http-equiv="content-type"/><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="app-id=com.levistrauss.customer" name="google-play-app"/><link href="/ngsa/favicon.png" rel="icon" type="image/png"/><link href="/ngsa/img/icons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="/ngsa/img/icons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/ngsa/img/icons/favicon-64x64.png" rel="icon" sizes="32x32" type="image/png"/><script>let appId = "1270092335";
#             if (typeof window === "object" && ["US","CA"].includes(window?.location?.pathname?.substring(1,3))) {
#                 appId = "1481624020";
#             }
# ...

# %%
#URL
url01 = "https://global.diesel.com/mens/denim/"

# Parameters
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Request to URL
page = requests.get(url01, headers=headers)

# Beautiful Soup object
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Innovative treatments and washes are used to create our unique, contemporary denim range. Shop on Diesel.com!" name="description"/>
# <meta content="Commerce Cloud Storefront Reference Architecture" name="keywords"/>
# <title>
#     Men's Jeans: Skinny, Slim, Bootcut | Diesel ®
# </title>
# <meta content="index,follow" name="robots"/>
# <link href="/on/demandware.static/Sites-DieselNonEcommerce-Site/-/default/dw47a79d00/imgs/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/on/demandware.static/Sites-DieselNonEcommerce-Site/-/default/dwc7656988/imgs/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# ...

# %% [markdown]
# Diesel não apresenta preço no site

# %%
#URL
url01 = "https://www.truereligion.com/mens-jeans-silhouette"

# Parameters
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Request to URL
page = requests.get(url01, headers=headers)

# Beautiful Soup object
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html class="ie6 oldie" lang="en"> <![endif]-->
# <!--[if IE 7]> <html class="ie7 oldie" lang="en"> <![endif]-->
# <!--[if IE 8]> <html class="ie8 oldie" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en"> <!--<![endif]-->
# <head>
# <meta content="3821cc023162/[5,-,-]" name="X-Yottaa-Metrics"/>
# <meta content="ob/1000000000100001100 si/38D1cc0231bc-1669907082-8359174104 tts/1669747979188 ti/5d66e8af4f1bbf5e32d89e22 ai/5d66e8af4f1bbf5e32d89eb5" name="X-Yottaa-Optimizations"/>
# <meta content="5d66e8af4f1bbf5e32d89db9" name="profile.id"/>
# <meta content="5d66e8af4f1bbf5e32d89e22" name="tod.id"/>
# <meta content="Default Profile" name="profile.name"/>
# <meta content="v~4b.62.0.0" name="resource.version"/>
# <meta content="5d66e8af4f1bbf5e32d89db9" name="adn.id"/>
# <meta content="0" name="shard.size"/>
# ...

# %%
# List which contains all products
products = soup.find('ul', 'search-result-items tiles-container page-0')

# %%
print(products)
# Out:
# <ul class="search-result-items tiles-container page-0" data-category="mens-jeans-silhouette" data-currentpage="0" data-page="0" data-pagesize="56">
# <li class="grid-tile odd-true in_stock" data-colors-to-show="HXIL" id="product-194922694017">
# <!-- CQuotient Activity Tracking (viewCategory-cquotient.js) -->
# <script type="text/javascript">//<!--
# /* <![CDATA[ */
# (function(){
# try {
#     if(window.CQuotient) {
# 	var cq_params = {};
#
# 	cq_params.cookieId = window.CQuotient.getCQCookieId();
# 	cq_params.userId = window.CQuotient.getCQUserId();
# 	cq_params.emailId = CQuotient.getCQHashedEmail();
# 	cq_params.loginId = CQuotient.getCQHashedLogin();
# 	cq_params.accumulate = true;
# 	cq_params.products = [{
# 	    id: '194922694017',
# 	    sku: ''
# 	}];
# 	cq_params.categoryId = 'mens-jeans-silhouette';
# 	cq_params.refinements = '[{\"name\":\"Category\",\"value\":\"mens-jeans-silhouette\"}]';
# 	cq_params.personalized = 'false';
# ...

# %%
product_id_category = products.find_all('a', 'name-link product-name')

# %%
product_id_category
# Out:
# [<a class="name-link product-name" data-name="ROCCO SKINNY JEAN" data-productid="194922694017" href="/rocco-skinny-jean/106692.html?color=HXIL&amp;showalts=false" title="ROCCO SKINNY JEAN">
#  ROCCO SKINNY JEAN
#  </a>,
#  <a class="name-link product-name" data-name="RICKY STRAIGHT JEAN" data-productid="194922794977" href="/ricky-straight-jean/106793.html?color=HYVM&amp;showalts=false" title="RICKY STRAIGHT JEAN">
#  RICKY STRAIGHT JEAN
#  </a>,
#  <a class="name-link product-name" data-name="RICKY STRAIGHT JEAN" data-productid="194922694321" href="/ricky-straight-jean/106694.html?color=HXKM&amp;showalts=false" title="RICKY STRAIGHT JEAN">
#  RICKY STRAIGHT JEAN
#  </a>,
#  <a class="name-link product-name" data-name="GENO SLIM JEAN" data-productid="194922702125" href="/geno-slim-jean/106699.html?color=HXFD&amp;showalts=false" title="GENO SLIM JEAN">
#  GENO SLIM JEAN
#  </a>,
# ...

# %%
product_name = products.find('a', 'name-link product-name')

# %%
product_name
# Out:
# <a class="name-link product-name" data-name="ROCCO SKINNY JEAN" data-productid="194922694017" href="/rocco-skinny-jean/106692.html?color=HXIL&amp;showalts=false" title="ROCCO SKINNY JEAN">
# ROCCO SKINNY JEAN
# </a>

# %%
product_id = [p.get('data-productid') for p in product_id_category]

# %%
product_id
# Out:
# ['194922694017',
#  '194922794977',
#  '194922694321',
#  '194922702125',
#  '194922702279',
#  '194922795424',
#  '194922694482',
#  '883682243534',
#  '194922753035',
#  '194922762655',
#  '194922688160',
#  '194922428124',
#  '194922694918',
#  '194922694642',
#  '194922805611',
#  '194922715699',
#  '194922770735',
#  '194922770599',
#  '194922583595',
#  '194922552423',
#  '194922549140',
#  '194922668957',
#  '194922583472',
#  '194922549010',
#  '194922537819',
#  '194922608366',
#  '194922551884',
#  '194922602562',
#  '194922692044',
#  '194922610192',
#  '194922695069',
#  '883682242957',
#  '883682807767',
#  '883682243091',
#  '883682243381',
#  '194922363708',
#  '883682243237',
#  '194922324143',
#  '194922364002',
#  '194922752878',
#  '194922364453',
#  '883682802007',
#  '194922762921',
#  '194922364156',
#  '194922765403',
#  '194922325942',
#  '194922763300',
#  '194922323061',
#  '194922324457',
#  '194922740950',
#  '194922325645',
#  '194922325799',
# ...

# %%
product_name = [p.get('data-name') for p in product_id_category]

# %%
product_name
# Out:
# ['ROCCO SKINNY JEAN',
#  'RICKY STRAIGHT JEAN',
#  'RICKY STRAIGHT JEAN',
#  'GENO SLIM JEAN',
#  'RICKY STRAIGHT JEAN',
#  'ROCCO SKINNY JEAN',
#  'GENO SLIM JEAN',
#  'RICKY BIG T STITCH STRAIGHT JEAN',
#  'ROCCO SUPER T STITCH SKINNY JEAN',
#  'RICKY SUPER T STITCH STRAIGHT JEAN',
#  'RICKY STRAIGHT JEAN',
#  'RICKY SUPER T STITCH STRAIGHT JEAN',
#  'ROCCO SKINNY JEAN',
#  'RICKY STRAIGHT JEAN',
#  'BILLY BOOTCUT JEAN',
#  'RICKY SUPER T STITCH STRAIGHT JEAN',
#  'RICKY SUPER T STITCH STRAIGHT JEAN',
#  'ROCCO SKINNY JEAN 32"',
#  'ROCCO QT BIG T STITCH SKINNY JEAN',
#  'ROCCO SUPER T STITCH SKINNY JEAN',
#  'ROCCO SKINNY JEAN',
#  'ROCCO SKINNY JEAN',
#  'RICKY BIG T STITCH STRAIGHT JEAN',
#  'RICKY STRAIGHT JEAN',
#  'ROCCO MOTO RENEGADE SKINNY JEAN',
#  'ROCCO SKINNY JEAN',
#  'RICKY TEAL STITCH SUPER T JEAN ',
#  'RICKY STRAIGHT JEAN',
#  'ROCCO SKINNY JEAN',
#  'ROCCO SKINNY JEAN',
#  'ROCCO MOTO STITCH SKINNY JEAN',
#  'RICKY STRAIGHT JEAN 32"',
# ...

# %%
product_price = products.find_all('span', itemprop='price')

# %%
product_price
# Out:
# [<span class="visually-hidden" content="49.00" itemprop="price">49.00</span>,
#  <span class="visually-hidden" content="49.00" itemprop="price">49.00</span>,
#  <span class="visually-hidden" content="49.00" itemprop="price">49.00</span>,
#  <span class="visually-hidden" content="49.00" itemprop="price">49.00</span>,
#  <span class="visually-hidden" content="49.00" itemprop="price">49.00</span>,
#  <span class="visually-hidden" content="49.00" itemprop="price">49.00</span>,
#  <span class="visually-hidden" content="49.00" itemprop="price">49.00</span>,
#  <span class="visually-hidden" content="139.30" itemprop="price">139.30</span>,
#  <span class="visually-hidden" content="167.30" itemprop="price">167.30</span>,
#  <span class="visually-hidden" content="167.30" itemprop="price">167.30</span>,
#  <span class="visually-hidden" content="95.40" itemprop="price">95.40</span>,
#  <span class="visually-hidden" content="160.30" itemprop="price">160.30</span>,
# ...

# %%
product_price = [p.get_text() for p in product_price]

# %%
product_price
# Out:
# ['49.00',
#  '49.00',
#  '49.00',
#  '49.00',
#  '49.00',
#  '49.00',
#  '49.00',
#  '139.30',
#  '167.30',
#  '167.30',
#  '95.40',
#  '160.30',
#  '49.00',
#  '49.00',
#  '79.50',
#  '149.40',
#  '149.40',
#  '89.50',
#  '99.98',
#  '99.98',
#  '74.98',
#  '67.48',
#  '99.50',
#  '74.98',
#  '63.99',
#  '79.50',
#  '99.98',
#  '67.48',
#  '79.50',
#  '79.50',
#  '109.50',
#  '104.30',
#  '143.40',
#  '104.30',
#  '104.30',
#  '119.40',
#  '104.30',
#  '111.30',
#  '139.30',
#  '124.50',
#  '99.50',
#  '95.40',
#  '119.50',
#  '99.50',
#  '119.50',
#  '111.30',
#  '119.50',
#  '114.50',
#  '111.30',
#  '95.60',
#  '79.50',
#  '111.30',
#  '143.40',
#  '143.40',
#  '119.40',
#  '137.40']

# %%
data = pd.DataFrame([product_id, product_name, product_price]).T
data.columns = ['product_id', 'product_name', 'product_price']
data['scrape_datetime'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
data.head()
# Out:
#      product_id         product_name product_price      scrape_datetime
# 0  194922694017    ROCCO SKINNY JEAN         49.00  2022-12-01 14:40:32
# 1  194922794977  RICKY STRAIGHT JEAN         49.00  2022-12-01 14:40:32
# 2  194922694321  RICKY STRAIGHT JEAN         49.00  2022-12-01 14:40:32
# 3  194922702125       GENO SLIM JEAN         49.00  2022-12-01 14:40:32
# 4  194922702279  RICKY STRAIGHT JEAN         49.00  2022-12-01 14:40:32

# %% [markdown]
# # Automation for each page

# %% [markdown]
# The chosen e-commerce was True Religion.

# %% [markdown]
# #### Page 01

# %%
#URL
url01 = "https://www.truereligion.com/mens-jeans-silhouette"

# Parameters
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Request to URL
page = requests.get(url01, headers=headers)

# Beautiful Soup object
soup = BeautifulSoup(page.text, 'html.parser')

# List which contains all products
products = soup.find('ul', 'search-result-items tiles-container page-0')

product_id_category = products.find_all('a', 'name-link product-name')

product_price = products.find_all('span', itemprop='price')

product_id = [p.get('data-productid') for p in product_id_category]

product_name = [p.get('data-name') for p in product_id_category]

product_price = [p.get_text() for p in product_price]

df01 = pd.DataFrame([product_id, product_name, product_price]).T
df01.columns = ['product_id', 'product_name', 'product_price']
df01['scrape_datetime'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
df01.head()
# Out:
#      product_id         product_name product_price      scrape_datetime
# 0  194922694017    ROCCO SKINNY JEAN         49.00  2022-12-01 15:03:06
# 1  194922794977  RICKY STRAIGHT JEAN         49.00  2022-12-01 15:03:06
# 2  194922694321  RICKY STRAIGHT JEAN         49.00  2022-12-01 15:03:06
# 3  194922702125       GENO SLIM JEAN         49.00  2022-12-01 15:03:06
# 4  194922795424    ROCCO SKINNY JEAN         49.00  2022-12-01 15:03:06

# %% [markdown]
# #### Page 02

# %%
#URL
url01 = "https://www.truereligion.com/mens-jeans-silhouette?start=56&sz=56"

# Parameters
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Request to URL
page = requests.get(url01, headers=headers)

# Beautiful Soup object
soup = BeautifulSoup(page.text, 'html.parser')

# List which contains all products
products = soup.find('ul', 'search-result-items tiles-container page-1')

product_id_category = products.find_all('a', 'name-link product-name')

product_price = products.find_all('span', itemprop='price')

product_id = [p.get('data-productid') for p in product_id_category]

product_name = [p.get('data-name') for p in product_id_category]

product_price = [p.get_text() for p in product_price]

df02 = pd.DataFrame([product_id, product_name, product_price]).T
df02.columns = ['product_id', 'product_name', 'product_price']
df02['scrape_datetime'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
df02.head()
# Out:
#      product_id                           product_name product_price  \
# 0  194922324600                RICKY STRAIGHT JEAN 32"        111.30
# 1  194922709414     RICKY SUPER T STITCH STRAIGHT JEAN        119.50
# 2  194922364316            ROCCO BIG T SKINNY JEAN 32"         99.50
# 3  194922804355            ROCCO BIG T SKINNY JEAN 32"         99.50
# 4  194922677133  ROCCO QT BIG T STITCH SKINNY JEAN 32"        119.50
#
#        scrape_datetime
# 0  2022-12-01 15:03:32
# 1  2022-12-01 15:03:32
# 2  2022-12-01 15:03:32
# 3  2022-12-01 15:03:32
# 4  2022-12-01 15:03:32

# %% [markdown]
# #### Page 03

# %%
#URL
url01 = "https://www.truereligion.com/mens-jeans-silhouette?start=112&sz=56"

# Parameters
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Request to URL
page = requests.get(url01, headers=headers)

# Beautiful Soup object
soup = BeautifulSoup(page.text, 'html.parser')

# List which contains all products
products = soup.find('ul', 'search-result-items tiles-container page-2')

product_id_category = products.find_all('a', 'name-link product-name')

product_price = products.find_all('span', itemprop='price')

product_id = [p.get('data-productid') for p in product_id_category]

product_name = [p.get('data-name') for p in product_id_category]

product_price = [p.get_text() for p in product_price]

df03 = pd.DataFrame([product_id, product_name, product_price]).T
df03.columns = ['product_id', 'product_name', 'product_price']
df03['scrape_datetime'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
df03.head()
# Out:
#      product_id                         product_name product_price  \
# 0  194922327113                ROCCO SKINNY JEAN 32"         89.40
# 1  883682511152              RICKY STRAIGHT JEAN 32"         89.40
# 2  194922744316  RICKY VINTAGE SUPER T STRAIGHT JEAN        181.30
# 3  194922323863                  RICKY STRAIGHT JEAN         74.50
# 4  194922694178                  RICKY STRAIGHT JEAN         95.40
#
#        scrape_datetime
# 0  2022-12-01 15:03:48
# 1  2022-12-01 15:03:48
# 2  2022-12-01 15:03:48
# 3  2022-12-01 15:03:48
# 4  2022-12-01 15:03:48

# %% [markdown]
# #### Page 04

# %%
#URL
url01 = "https://www.truereligion.com/mens-jeans-silhouette?start=168&sz=56"

# Parameters
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Request to URL
page = requests.get(url01, headers=headers)

# Beautiful Soup object
soup = BeautifulSoup(page.text, 'html.parser')

# List which contains all products
products = soup.find('ul', 'search-result-items tiles-container page-3')

product_id_category = products.find_all('a', 'name-link product-name')

product_price = products.find_all('span', itemprop='price')

product_id = [p.get('data-productid') for p in product_id_category]

product_name = [p.get('data-name') for p in product_id_category]

product_price = [p.get_text() for p in product_price]

df04 = pd.DataFrame([product_id, product_name, product_price]).T
df04.columns = ['product_id', 'product_name', 'product_price']
df04['scrape_datetime'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
df04.head()
# Out:
#      product_id                      product_name product_price  \
# 0  194922417937  RICKY BIG T STITCH STRAIGHT JEAN         69.98
# 1  194922585629             ROCCO SKINNY JEAN 32"         67.48
# 2  194922351781             ROCCO SKINNY JEAN 34"         59.98
# 3  194922609950               RICKY STRAIGHT JEAN         79.50
# 4  194922391992    ROCCO BIG T STITCH SKINNY JEAN         55.99
#
#        scrape_datetime
# 0  2022-12-01 15:03:57
# 1  2022-12-01 15:03:57
# 2  2022-12-01 15:03:57
# 3  2022-12-01 15:03:57
# 4  2022-12-01 15:03:57

# %%
df01.shape
# Out:
# (56, 4)

# %%
df02.shape
# Out:
# (56, 4)

# %%
df03.shape
# Out:
# (56, 4)

# %%
df04.shape
# Out:
# (13, 4)

# %% [markdown]
# # Automation using one single page for all products

# %%
#URL (start = 0 and size = 190)
url01 = "https://www.truereligion.com/mens-jeans-silhouette?start=0&sz=190"

# Parameters
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Request to URL
page = requests.get(url01, headers=headers)

# Beautiful Soup object
soup = BeautifulSoup(page.text, 'html.parser')

# List which contains all products
products = soup.find('ul', 'search-result-items tiles-container page-0')

product_id_category = products.find_all('a', 'name-link product-name')

product_price = products.find_all('span', itemprop='price')

href = products.find_all('a', 'name-link product-name')

product_id = [p.get('data-productid') for p in product_id_category]

product_name = [p.get('data-name') for p in product_id_category]

product_price = [p.get_text() for p in product_price]

href = [p.get('href') for p in href]

data = pd.DataFrame([product_id, href, product_name, product_price]).T
data.columns = ['product_id', 'style_id', 'product_name', 'product_price']
data['scrape_datetime'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
data.head()
# Out:
#      product_id                                           style_id  \
# 0  194922694017  /rocco-skinny-jean/106692.html?color=HXIL&show...
# 1  194922794977  /ricky-straight-jean/106793.html?color=HYVM&sh...
# 2  194922694321  /ricky-straight-jean/106694.html?color=HXKM&sh...
# 3  194922702125  /geno-slim-jean/106699.html?color=HXFD&showalt...
# 4  194922795424  /rocco-skinny-jean/106795.html?color=HYSD&show...
#
#           product_name product_price      scrape_datetime
# 0    ROCCO SKINNY JEAN         49.00  2022-12-01 15:57:44
# 1  RICKY STRAIGHT JEAN         49.00  2022-12-01 15:57:44
# 2  RICKY STRAIGHT JEAN         49.00  2022-12-01 15:57:44
# 3       GENO SLIM JEAN         49.00  2022-12-01 15:57:44
# 4    ROCCO SKINNY JEAN         49.00  2022-12-01 15:57:44

# %%
data.shape
# Out:
# (181, 5)

# %%
len(href)
# Out:
# 181

# %%
data['style_id'] = data['style_id'].apply(lambda x: int( re.search('\d+', x).group(0)) if pd.notnull(x) else x)

# %%
data.head()
# Out:
#      product_id  style_id         product_name product_price  \
# 0  194922694017    106692    ROCCO SKINNY JEAN         49.00
# 1  194922794977    106793  RICKY STRAIGHT JEAN         49.00
# 2  194922694321    106694  RICKY STRAIGHT JEAN         49.00
# 3  194922702125    106699       GENO SLIM JEAN         49.00
# 4  194922795424    106795    ROCCO SKINNY JEAN         49.00
#
#        scrape_datetime
# 0  2022-12-01 15:57:44
# 1  2022-12-01 15:57:44
# 2  2022-12-01 15:57:44
# 3  2022-12-01 15:57:44
# 4  2022-12-01 15:57:44

# %%
data.dtypes

# %%
data['style_id'] = data['style_id'].astype(str)
data.dtypes

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

#empty dataframe
df_final = pd.DataFrame()

# Auxiliar list in order to monitor new columns
aux = []

# All columns found on website
df_pattern = pd.DataFrame(columns= ['Composition', 'Fit', 'Size'])

for i in range(len(data)):

    #API request
    # conteúdo de headers é padrão
    url02 = "https://www.truereligion.com/rocco-skinny-jean/" + data.loc[i, 'style_id'] + ".html?color=HXIL&showalts=false"

    page = requests.get(url02, headers=headers)

    #Beautiful Soup object
    soup = BeautifulSoup(page.text, 'html.parser')

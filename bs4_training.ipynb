# %% [markdown]
# # Estudos da biblioteca BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

# %% [markdown]
# Dentro do soup, nós temos acesso a todo o HTML:

# %%
soup
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %% [markdown]
# #### Filtrando informação

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.story

# %%
soup.body
# Out:
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>

# %%
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.html
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
soup.head
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
soup.body.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %% [markdown]
# #### Filtrando informação de parágrafo por índice

# %%
soup.find_all('p')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
soup.find_all('p')[0]
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.find_all('p')[1]
# Out:
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>

# %%
soup.find_all('p')[2]
# Out:
# <p class="story">...</p>

# %% [markdown]
# #### Filtrando informação de parágrafo por nome

# %%
soup.find_all('p', 'story')
# Out:
# [<p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
soup.find_all('p', 'title')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>]

# %% [markdown]
# #### Filtrando informação da tag a (link)

# %%
soup.find_all('a')[0]
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all('a')[1]
# Out:
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %%
soup.find_all('a')[2]
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %% [markdown]
# #### Filtrando informação a partir do "id"

# %%
soup.find_all('a', id='link1')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %%
soup.find_all('a', id='link2')
# Out:
# [<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>]

# %%
soup.find_all('a', id='link3')
# Out:
# [<a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# #### Filtrando apenas o texto

# %%
soup.find_all('a', id='link1')[0].get_text()
# Out:
# 'Elsie'

# %%
soup.find_all('a', id='link1')[0].string
# Out:
# 'Elsie'

# %% [markdown]
# # Extração dos dados que planejamos

# %%
import pandas as pd
import numpy as np
import requests

from bs4 import BeautifulSoup
from datetime import datetime

# %%
url = "https://www2.hm.com/en_us/men/products/jeans.html"

# conteúdo de headers é padrão
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
page = requests.get(url, headers=headers)

# %%
page.text
# Out:
# '<!DOCTYPE HTML>\n<html lang="en-US" is-in-aem="false" class="no-js en-us" ng-app="hmApp" >\n    \n\n\n    <head>\r\n    \r\n  <script type="text/javascript" src="/ruxitagentjs_ICA27Vfgjoqru_10227211018092056.js" data-dtconfig="rid=RID_-1928280405|rpid=1730055537|domain=hmgroup.tech|reportUrl=/rb_58096d71-709f-4335-a959-44a125e69dd3|app=7a6f08f8d839fa96|rcdec=1209600000|featureHash=ICA27Vfgjoqru|vcv=2|rdnt=1|uxrgce=1|bp=2|srmcrv=10|cuc=gbmnxyo0|mel=100000|dpvc=1|lastModification=1642644240929|dtVersion=10227211018092056|srmcrl=1|tp=500,50,0,1|uxdcw=1500|agentUri=/ruxitagentjs_ICA27Vfgjoqru_10227211018092056.js"></script><link rel="dns-prefetch" href="https://s1-cdn.hm.com"/>\r\n  <link rel="preconnect" href="https://s1-cdn.hm.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://tags.tiqcdn.com"/>\r\n  <link rel="preconnect" href="https://tags.tiqcdn.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://lp2.hm.com"/>\r\n  <link rel="preconnect" href="https://lp2.hm.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://cdn-pci.optimizely.com"/>\r\n  <link rel="preconnect" href="https://cdn-pci.optimizely.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://s.go-mpulse.net"/>\r\n  <link rel="preconnect" href="https://s.go-mpulse.net" crossorigin/>\r\n\n\t\n\t\t<script type="text/javascript" src="https://cdn.cookielaw.org/consent/511a7faf-cc2d-4b69-86fb-a37761829422/OtAutoBlock.js"></script>\n\t\t<script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" data-document-language="true" type="text/javascript" charset="UTF-8" data-domain-script="511a7faf-cc2d-4b69-86fb-a37761829422"></script>\n    \t\n    \t\t<script type="text/javascript">function OptanonWrapper() {\r\n            if (window.location.pathname.includes(\'customer-service\') &&\r\n                (window.location.pathname.includes(\'en_us\') || window.location.pathname.includes(\'es_us\'))) {\r\n                var newItem = document.createElement("div");\r\n                newItem.id = \'svgButtons\';\r\n\r\n                // Up svg\r\n                const iconSvgUp = document.createElementNS(\'http://www.w3.org/2000/svg\', \'svg\');\r\n                const iconPathUp = document.createElementNS(\r\n                    \'http://www.w3.org/2000/svg\',\r\n                    \'path\'\r\n                );\r\n\r\n                iconSvgUp.setAttribute(\'fill\', \'#222222\');\r\n                iconSvgUp.setAttribute(\'viewBox\', \'4 2 8 8\');\r\n                iconSvgUp.setAttribute(\'width\', 16);\r\n                iconSvgUp.setAttribute(\'height\', 16);\r\n                iconSvgUp.setAttribute(\'title\', \'Expand Cookie banner\');\r\n                iconPathUp.setAttribute(\r\n                    \'d\',\r\n                    \'M4,14.3368542 L4,6.33685425 L5,6.33685425 L5,13.3368542 L12,13.3368542 L12,14.3368542 L4,14.3368542 Z\'\r\n                );\r\n\r\n                iconPathUp.setAttribute(\r\n                    \'transform\', \'translate(8.000000, 10.336854) scale(1, -1) rotate(-45.000000) translate(-8.000000, -10.336854)\');\r\n                iconSvgUp.appendChild(iconPathUp);\r\n                iconSvgUp.addEventListener(\'click\', () => handleClick(\'Up\'));\r\n                newItem.appendChild(iconSvgUp);\r\n                iconSvgUp.style.float = \'right\';\r\n\r\n                // Down svg\r\n                const iconSvgDown = document.createElementNS(\'http://www.w3.org/2000/svg\', \'svg\');\r\n                const iconPathDown = document.createElementNS(\r\n                    \'http://www.w3.org/2000/svg\',\r\n                    \'path\'\r\n                );\r\n\r\n                iconSvgDown.setAttribute(\'fill\', \'#222222\');\r\n                iconSvgDown.setAttribute(\'viewBox\', \'4 2 8 8\');\r\n                iconSvgDown.setAttribute(\'width\', 16);\r\n                iconSvgDown.setAttribute(\'height\', 16);\r\n                iconSvgDown.setAttribute(\'title\', \'C ...

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <html class="no-js en-us" is-in-aem="false" lang="en-US" ng-app="hmApp">
# <head>
# <script data-dtconfig="rid=RID_-1928280405|rpid=1730055537|domain=hmgroup.tech|reportUrl=/rb_58096d71-709f-4335-a959-44a125e69dd3|app=7a6f08f8d839fa96|rcdec=1209600000|featureHash=ICA27Vfgjoqru|vcv=2|rdnt=1|uxrgce=1|bp=2|srmcrv=10|cuc=gbmnxyo0|mel=100000|dpvc=1|lastModification=1642644240929|dtVersion=10227211018092056|srmcrl=1|tp=500,50,0,1|uxdcw=1500|agentUri=/ruxitagentjs_ICA27Vfgjoqru_10227211018092056.js" src="/ruxitagentjs_ICA27Vfgjoqru_10227211018092056.js" type="text/javascript"></script><link href="https://s1-cdn.hm.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://s1-cdn.hm.com" rel="preconnect"/>
# <link href="https://tags.tiqcdn.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://tags.tiqcdn.com" rel="preconnect"/>
# <link href="https://lp2.hm.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://lp2.hm.com" rel="preconnect"/>
# <link href="https://cdn-pci.optimizely.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://cdn-pci.optimizely.com" rel="preconnect"/>
# <link href="https://s.go-mpulse.net" rel="dns-prefetch"/>
# <link crossorigin="" href="https://s.go-mpulse.net" rel="preconnect"/>
# <script src="https://cdn.cookielaw.org/consent/511a7faf-cc2d-4b69-86fb-a37761829422/OtAutoBlock.js" type="text/javascript"></script>
# <script charset="UTF-8" data-document-language="true" data-domain-script="511a7faf-cc2d-4b69-86fb-a37761829422" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">function OptanonWrapper() {
#             if (window.location.pathname.includes('customer-service') &&
#                 (window.location.pathname.includes('en_us') || window.location.pathname.includes('es_us'))) {
#                 var newItem = document.createElement("div");
#                 newItem.id = 'svgButtons';
#
#                 // Up svg
#                 const iconSvgUp = document.createElementNS('http://www.w3.org/2000/svg', 'svg');
#                 const iconPathUp = document.createElementNS(
#                     'http://www.w3.org/2000/svg',
#                     'path'
#                 );
#
#                 iconSvgUp.setAttribute('fill', '#222222');
#                 iconSvgUp.setAttribute('viewBox', '4 2 8 8');
#                 iconSvgUp.setAttribute('width', 16);
#                 iconSvgUp.setAttribute('height', 16);
#                 iconSvgUp.setAttribute('title', 'Expand Cookie banner');
#                 iconPathUp.setAttribute(
#                     'd',
#                     'M4,14.3368542 L4,6.33685425 L5,6.33685425 L5,13.3368542 L12,13.3368542 L12,14.3368542 L4,14.3368542 Z'
#                 );
#
#                 iconPathUp.setAttribute(
#                     'transform', 'translate(8.000000, 10.336854) scale(1, -1) rotate(-45.000000) translate(-8.000000, -10.336854)');
#                 iconSvgUp.appendChild(iconPathUp);
#                 iconSvgUp.addEventListener('click', () => handleClick('Up'));
#                 newItem.appendChild(iconSvgUp);
#                 iconSvgUp.style.float = 'right';
#
#                 // Down svg
#                 const iconSvgDown = document.createElementNS('http://www.w3.org/2000/svg', 'svg');
#                 const iconPathDown = document.createElementNS(
#                     'http://www.w3.org/2000/svg',
#                     'path'
#                 );
#
#                 iconSvgDown.setAttribute('fill', '#222222');
#                 iconSvgDown.setAttribute('viewBox', '4 2 8 8');
#                 iconSvgDown.setAttribute('width', 16);
#                 iconSvgDown.setAttribute('height', 16);
#                 iconSvgDown.setAttribute('title', 'Collapse Cookie banner');
#                 iconPathDown.setAttribute(
#                     'd',
#                     'M4,9.65685425 L4,1.65685425 L5,1.65685425 L5,8.65685425 L12,8.65685425 L12,9.65685425 L4,9.65685425 Z'
#                 );
#
#                 iconPathDown.setAttribute(
#                     'transform', 'translate(8.000000, 5.656854) rotate(-45.000000) translate(-8.000000, -5.656854)');
#                 iconSvgDown.appendChild(iconPathDown);
#                 iconSvgDown.addEventListener('click', () => handleClick('Down'));
#                 newItem.appendChild(iconSvgDown);
#                 iconSvgDown.style.display = 'none'
#                 iconSvgDown.style.float = 'right';
#                 iconSvgDown.style.marginBottom = '16px';
#
#                 //Adding svg's to the top of title in banner
#                 var list = document.getElementById("onetrust-banner-sdk").childNodes[0];
#                 list.insertBefore(newItem, list.childNodes[0]);
#                 list.style.padding = '20px 40px 40px 40px';
#
#                 document.getElementById('onetrust-group-container').style.display = 'none';
#                 document.getElementById('onetrust-button-group-parent').style.display = 'none';
#
#                 function handleClick(text) {
#                     let buttons = document.getElementById('svgButtons');
#                     if (text === 'Up') {
#                         document.getElementById('onetrust-group-container').style.display = 'block';
#                         document.getElementById('onetrust-button-group-parent').style.display = 'block';
#                         buttons.firstChild.style.display = 'none';
#                         buttons.lastChild.style.display = 'block';
#                     } else {
#                         document.getElementById('onetrust-group-container').style.display = 'none';
#                         document.getElementById('onetrust-button-group-parent').style.display = 'none';
#                         buttons.firstChild.style.display = 'block';
#                         buttons.lastChild.style.display = 'none';
#                     }
#                 }
#             }
#         }</script>
# <link as="script" href="https://s1-cdn.hm.com/global/frontend/loader.js" rel="preload"/>
# <script src="https://s1-cdn.hm.com/global/frontend/loader.js" type="text/javascript"></script>
# <link href="https://s1-cdn.hm.com/global/fonts/4.0.15/hm/css/fonts_en_us.css" rel="stylesheet"/>
# <style type="text/css">/* atf version: 0.18.2 */html{overflow:hidden}body{background-color:#faf9f8;margin:0;font-size:.8125rem;line-height:20px;color:#000;font-family:"HM Sans Regular","ヒラギノ角ゴ Pro W3","Hiragino Kaku Gothic Pro",Osaka,"メイリオ",Meiryo,"ＭＳ Ｐゴシック","MS PGothic",sans-serif;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;overflow-x:hidden}body.mobile-app::before{content:"";display:block;position:fixed;width:100%;height:100vh;background-color:#faf9f8;z-index:10000}a{color:inherit}button{border:0;background-color:transparent}.hide-content{border:0;clip:rect(0 0 0 0);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px}.header-global{background:#faf9f8;height:100vh;left:0;padding:21px 0;position:fixed;top:0;width:100%;z-index:1001}.menu{position:relative;display:inline-block;width:100%}.menu a{text-decoration:none}.menu__hm{display:block;width:43px;height:30px;text-indent:-9999px;overflow:hidden;margin:0 0 0 53px}.menu__hm::before{background-image:url("data:image/svg+xml;charset=US-ASCII,%3Csvg%20width%3D%22370%22%20height%3D%22244%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20xmlns%3Axlink%3D%22http%3A%2F%2Fwww.w3.org%2F1999%2Fxlink%22%3E%3Ctitle%3E1.%20Foundation%2FLogotypes%2FH%26amp%3BM%2FRed%3C%2Ftitle%3E%3Cdefs%3E%3Cpath%20d%3D%22M259.895%207.413c13.424-6.618%2020.087-5.737%2020.232.946.19%208.7-1.098%2020.23-2.016%2028.604-4.983%2045.423-13.32%2082.543-13.954%20129.19%2021.94-56.802%2040.345-96.278%2064.03-144.909%207.53-15.47%2012.325-12.593%2018.503-15.343%2024.082-10.715%2024.984-4.133%2021.837%208.95-11.686%2048.552-41.54%20201.376-46.114%20224.907-1.328%206.807-8.715%203.923-10.644%201.26-8.57-11.85-18.225-12.036-17.14-19.919%205.37-39.233%2024.71-137.666%2029.75-160.863-25.719%2052.696-52.37%20118.566-66.053%20155.914-2.907%207.931-8.188%207.35-11.48%201.546-4.63-8.15-13.61-12.312-15.093-21.943-4.702-30.628%205.37-89.003%206.773-125.936-13.994%2040.342-37.49%20118.67-47.782%20154.057-4.256%2014.643-18.382%2012.253-14.627-2.018%2015.642-59.389%2049.326-164.425%2063.915-202.198%203.427-8.874%2012.406-8.569%2019.863-12.245zM174.6.115c4.26%201.025%203.913%206.05%201.31%2012.912-7.682%2020.247-18.335%2046.847-30.516%2078.212%207.658-.874%2011.811-1.17%2011.811-1.17%2010.994-1.358%2013.041%204.139%209.946%209.99-2.466%204.664-5.436%201.554-15.724%2016.89-5.796%208.642-15.259%2010.924-20.515%2012.076-12.662%2033.523-26.23%2070.916-39.415%20110.77-1.919%205.804-7.524%204.532-9.209%202.174-6.192-8.647-10.758-8.933-15.558-15.927-.577-1.132-1.706-2.672-1.027-5.448%203.53-14.425%2012.901-44.067%2027.156-83.091-17.958%203.892-37.387%208.076-45.408%209.94-9.626%2025.445-19.014%2050.967-27.908%2076.18-5.518%2015.64-19.88%2012.617-14.84-2.165%208.028-23.548%2016.89-48.004%2025.776-71.72-9.948-1.063-13.313-8.088-18.873-13.958-2.147-2.267-6.828-1.948-9.12-5.127-4.123-5.711-3.712-8.248%205.81-10.996a955.318%20955.318%200%200%201%2037.464-9.998c16.09-41.524%2030.63-77.144%2038.38-96.151C90.114-1.138%20105.514.226%2099.664%2014.674c-11.889%2029.363-24.079%2059.867-36.11%2090.799a880.98%20880.98%200%200%201%2044.748-8.87%202312.644%202312.644%200%200%201%2034.62-83.968c.845-1.937%203.31-4.678%205.878-5.118%208.092-1.385%2021.251-8.498%2025.8-7.402zm-27.552%20190.077c1.265-.773%202.524-1.715%203.767-2.75a756.514%20756.514%200%200%201-2.82-8.468%20139.528%20139.528%200%200%200-2.752%203.638c-5.386%207.396-2.197%2010.028%201.805%207.58zm7.167-35.065c6.67-7.53-6.516-10.681-3.48.836.17.65.382%201.413.62%202.254a98.19%2098.19%200%200%200%202.86-3.09zm6.941%2022.695c6.602-5.721%2012.908-.046%206.38%209.628-1.404%202.08-2.99%204.318-4.729%206.522a193.17%20193.17%200%200%200%202.146%205.877c3.375%208.654-5.488%2010.824-8.345%203.656-.25-.626-.51-1.297-.778-1.995-5.387%204.772-11.618%207.777-18.275%205.707-10.954-3.407-13.74-18.83-3.514-30.711%204.103-4.767%207.191-8.074%209.771-10.716a251.947%20251.947%200%200%201-1.819-6.17c-1.328-4.81-2.527-10.416%202.287-16.13%209.027-10.712%2029. ...
# <link rel="stylesheet" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop/ie8.min.css" type="text/css">
# <script src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop/ie8.min.js"></script>
# <![endif]-->
# <script src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/jquery.min.js"></script>
# <script src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/head.min.14.1.58.js"></script>
# <!-- to include grunticon -->
# <script>var clientlibsVersion = '.14.1.58';</script>
# <!-- to include grunticon -->
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <script async="" src="https://idservice.hm.com/"></script>
# <script type="text/javascript"></script><script src="https://cdn-pci.optimizely.com/public/2125530039/s/hm_us.js"></script>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="/en_us/men/shop-by-product/jeans" name="contentPath">
# <meta content="Jeans" name="keywords">
# <meta content="Add classic cool to your wardrobe with H&amp;M's collection of men's jeans. Shop online for skinny, slim and straight styles in a range of colors and washes." name="description"/>
# <meta content="Men's Jeans | Ripped &amp; Skinny Jeans | H&amp;M US" property="og:title"/>
# <meta content="Add classic cool to your wardrobe with H&amp;M's collection of men's jeans. Shop online for skinny, slim and straight styles in a range of colors and washes." property="og:description"/>
# <meta content="H&amp;M" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www2.hm.com/en_us/men/products/jeans.html" property="og:url"/>
# <meta content="https://www2.hm.com/content/dam/courtesypageimages/down_for_maintenance.jpeg" property="og:image"/>
# <meta content="1433700643510498" property="fb:app_id"/>
# <link href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/favicon/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/favicon/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="https://www2.hm.com/en_us/men/products/jeans.html" rel="canonical">
# <title>Men's Jeans | Ripped &amp; Skinny Jeans | H&amp;M US</title>
# <meta content="hmgoe://www2.hm.com/en_us/men/products/jeans.html" property="al:ios:url">
# <meta content="834465911" property="al:ios:app_store_id">
# <meta content="H&amp;M App" property="al:ios:app_name">
# <meta content="hmgoe://www2.hm.com/en_us/men/products/jeans.html" property="al:android:url">
# <meta content="com.hm.goe.prd.am" property="al:android:package">
# <meta content="H&amp;M" property="al:android:app_name"/>
# <script src="/en_us/metrics/default/touchpoint.js" type="text/javascript"></script>
# <meta property="og:open_graph_title"/>
# <meta property="og:open_graph_description"/>
# <meta property="og:open_graph_url"/>
# <meta property="og:open_graph_image"/>
# <meta property="og:open_graph_video"/>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="EPMEN-VPFQ4-GM3WK-22BJD-TU9B7",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"EPMEN-VPFQ4-GM3WK-22BJD-TU9B7";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="woalqalilh6fcypo4usq-f-724e423e8-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"32","ak.cp":"271055","ak.ai":parseInt("171241",10),"ak.ol":"0","ak.cr":154,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"2f8c66a8","ak.r":40471,"ak.a2":n,"ak.m":"b","ak.n":"essl","ak.bpcip":"179.128.184.0","ak.cport":63380,"ak.gh":"23.54.22.206","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1643046181","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"309","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></meta></meta></meta></meta></meta></link></meta></meta></head><body class="subdepartment-page" ng-class="{pre_shopping_sale_countdown:preshoppingStartingSoon}" ng-controller="HmA ...
# <div class="dictionary parbase"></div>
# <script type="text/javascript">
#
#         var hm = hm || {};
#         hm.options = hm.options || {};
#         hm.options.tealiumPageId = 'Men : Shopbyproduct : Jeans : Viewall';
#
# </script><!-- Header -->
# <script>
#     var hm = hm || {};
#
#     (function(hm){
#
#     	hm.MultiCountry = function() {
#
#     		function readCookieValue(name) {
#
#     			var cookieAll = document.cookie.split(';'),
#     				cookieValue;
#     			if(cookieAll && cookieAll.length){
#     				cookieAll.some(function(entry){
#     					entry = entry.trim();
#     					var cookiePair = entry.split('=');
#     					if(cookiePair[0]==name){
#     						cookieValue = decodeURIComponent(cookiePair[1]);
#     						return true;
#     					}
#     				});
#     			}
#     			return cookieValue;
#     		};
#
#     		this.getCountryName = function getCountryCode(cookieName) {
#     			var cookieValue = readCookieValue(cookieName);
#     			return cookieValue;
#     		};
#
#     		this.getCountryCode = function getCountryCode(cookieName) {
#
#     			 var cookieValue = readCookieValue(cookieName),
#     				countryCode = "";
#     			if(cookieValue) {
#     				var match = /(?:^[a-z]{2}_)?([A-Z]{2})$/.exec(cookieValue);
#     				if(match) {
#     					countryCode = match[1];
#     				}
#     			}
#     			return countryCode;
#     		};
#
#     		this.getLocale = function getLocale(cookieName, language) {
#
#     		   var locale = "";
#     		   if(!language) {
#     				var cookieValue = readCookieValue(cookieName);
#     				if(cookieValue && cookieValue.search(/^[a-z]{2}_[A-Z]{2}$/) == 0) {
#     					locale = cookieValue;
#     				}
#     		   } else {
#     				var country = this.getCountryCode(cookieName);
#     				if(country.length) {
#     					locale =  language + "_" + country;
#     				}
#     		   }
#     		   return locale;
#     		};
#
#     		this.getLanguage = function getLanguage(cookieName) {
#     		   var language = this.getLocale(cookieName);
#     		   if(!language || !language.length) {
#     				return "";
#     		   }
#     		   else {
#     				return language.substring(0,2);
#     		   }
#     		};
#
#     		this.createCookie = function createCookie(cookieName, language, country) {
#     	        var d = new Date(),
#     			exdays = 182;
#     			d.setTime(d.getTime() + (exdays*24*60*60*1000));
#     			var expires = "expires="+ d.toUTCString();
#     			var userAgent = navigator.userAgent;
#     			var userAgentLowerCase;
#
#     			if(userAgent !== "undefined" && userAgent){
#     				userAgentLowerCase = userAgent.toLowerCase();
# 					if(userAgentLowerCase.includes("chrome")){
# 	    	        	var cookie = cookieName + "=" + language + "_" + country + "; " + expires + ";SameSite=None; Secure; domain=.hm.com; path=/";
# 	    	        } else {
# 						var cookie = cookieName + "=" + language + "_" + country + "; " + expires + "; domain=.hm.com; Secure; path=/";
# 	    	        }
# 	    	    } else {
# 					var cookie = cookieName + "=" + language + "_" + country + "; " + expires + "; domain=.hm.com; Secure; path=/";
# 	    	    }
#     	        return cookie;
#     		};
#
#     	};
#
#     	hm.multiCountry = new hm.MultiCountry();
#     })(hm);
#
#
#     hm.options = hm.options || {};
#     hm.options.omnicredit = hm.options.omnicredit || {};
#     hm.options.klarna = hm.options.klarna || {};
#     var wpwlOptions = window.wpwlOptions || {};
#
#     var localeInfo ={};
#     localeInfo.locale = "en_US";
# 	localeInfo.country = "US";
#
#     hm.i18n = hm.i18n || {};
#
#     hm.options.forceUtagForAndroid = false;
#     hm.options.forceUtagForIOS = false;
#
#     hm.options.isLoyaltyMarket = 'true';
#
#     hm.options.isCiamEnabled = 'false';
#
#     hm.options.product = {
#       removeFromCartServiceUrl: 'remove_from_cart_response.json',
#       country: 'hm-us',
#       locale: 'en_us',
#       getFavoritesService: '/en_us/favourites/productCodes',
#       addFavoriteService: '/en_us/favourites/addItem',
#       removeFavoriteService: '/en_us/favourites/removeItem',
# 	  addToCartServiceUrl: '/en_us/cart/add',
# 	  esalesServicePathname: '/pra/panel/product-detail-page',
# 	  clubMemberPriceLabel: 'Member price',
# 	  modelHeightGarmentSizePDPLabel: 'The model is {0} and wears a size {1}',
# 	  sizePDPLabel: 'Size'
#     };
#
#     var productAvailabilityServiceUrl = '/hmwebservices/service/product/{site_code}/availability/{product_code}.json';
# 	var countryForAvailability = hm.options.product.locale;
# 	if(countryForAvailability.indexOf("_")>=0){
# 		countryForAvailability = hm.options.product.locale.split("_")[1];
# 	}
#     productAvailabilityServiceUrl = productAvailabilityServiceUrl.replace("{site_code}",countryForAvailability);
#     hm.options.product.productAvailabilityServiceUrl = productAvailabilityServiceUrl;
#
#     hm.options.clubSetup = {
#     		clubSetupCountry : 'hm-us',
#     		clubSetupTierLevelLimit : '500',
#     		clubSetupCashBackEnabled : 'true',
#     		clubSetupAmount : '5',
#     		clubSetupCashBackCapYear : '99',
#     		clubSetupCashBackCapRolling : '25',
#     		clubSetupCashBackPoints : '200',
#     		clubSetupRatingReviewEnabled : 'false',
#     		clubSetupRatingreview : '0',
#     		clubSetupReviewPointsCapRolling : '0'
#
#     };
#     hm.options.clubUpgrade = {
#     	confirmationMessage: 'You&#039;re now a member!'
#     };
#
#     hm.options.esalesPra10 = {
#     		url: '/en_us/pra/panel/pra10'
#     };
#
#     hm.options.praSlideNoText = {
#    		slideBulletText: '[slideNumberLabel]'
#   	};
#
#     hm.options.gdpr = {
#     	    enabled: 'false',
#     	    dateStart: '2018-05-14T00:00:00.000+02:00',
#     	    dateEnd: '2021-05-01T00:00:00.000+02:00',
#     	    url:'https://www2.hm.com/en_us/customer-service/legal-and-privacy/privacy-link.html'
#     	  };
#
#     hm.options.orders = {
#     	    getOrders: '/mock/getOrders',
#     	    offset: '5',
#     	    missingImageUrl: '/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/images/kaff.png'
#     	  };
#     hm.options.pra = {
#     		pra1: '/en_us/pra/panel/product-detail-page',
#     	    pra6: '/en_us/pra/panel/sub-department-page',
#    	     	pra10: '/en_us/pra/panel/pra10',
#     	   	pra11: '/en_us/pra/panel/sale-department-page',
#     	    pra3: '/en_us/pra/panel/shopping-bag-page',
#     	    pra4: '/en_us/pra/panel/shopping-bag-page'
#          };
#     hm.options.omnicredit.isOmnicreditMarket = true;
#
#     hm.options.klarna.showAlerts = true;
#     hm.options.enableQuestionairre = false;
#
#        hm.i18n = {
#        	sizeGuide:  {
# 			   back: 'Back',
# 			   sizeGuide: 'Size Guide',
# 			   findMySize: 'Find my size',
# 			   howToMeasure: 'HOW TO MEASURE',
# 			   selectSizeRange: 'Select Size Range',
# 			   sizeGuideLinkText: 'SIZE GUIDE - ALL PRODUCTS',
# 			   noSizeGuideTitle: 'Oh, hello there!',
# 			   noSizeGuideDescription: 'We don&#039;t have a size guide available for this product at the moment.',
# 			   noSizeGuideClose: 'CLOSE'
# 		},
#    		 favorite: {
#    	   	        favoritesErrorText: 'Sorry, we were unable to move  your item to Favorites. Please try again later.',
#    	   	        addToFavoritesErrorHeading: 'Item not added to Favorites',
#    	   	        removeFavoritesErrorHeading: 'ERROR WHEN REMOVING FAVORITE',
#    	   	        moveToBagErrorHeading: 'Item not moved to your Shopping Bag',
#    	   	     	moveToFavoritesErrorHeading: 'Oops… Favorites is full',
#    	   	    	fullFavoritesListError: 'Sorry, Favorites is full so we can&#039;t add this item. If you really love this item, delete one of your saved items to make room!',
#    	   	        fullFavoritesListErrorHeading: 'Oops… Favorites is full',
#    	   	    	activeText: 'Saved to favorites',
#    	  	      	inactiveText: 'Not saved to favorites'
#    	   	},
#    	 	quickbuy: {
#    	   	      viewMore: 'Show more',
#    	   	      add: 'Add to bag',
#    	   	      selectSize: 'Select size',
#    	   	      fewPiecesLeft: 'Few pieces left',
#    	   	      soldOut: 'Sold out',
#     	 	  sizeGuide: 'Size guide'
#    	   	    },
#    	 	getthelook: {
#    	   	      title: 'Get the look!',
#    	   	      add: 'ADD TO BAG',
#    	   	      addedToBag: 'Added to bag'
#    	   	    },
#    	 	gdpr: {
# 	      	headerText: 'WE CARE ABOUT YOUR PRIVACY!',
#    	  		bodyText:'Your privacy is important to us which is why we want to inform you on our updated Privacy Notice. To give you a more transparent and clear information on how we process your personal data, we have divided the Privacy Notice into different chapters. Depending on if you are a subscriber, member or if you have an H&amp;M Account, different parts of the notice will apply to you. In each chapter, we describe in more detail what personal data we have about you and how we use it. We have also increased the information on your rights, for example how to get access to your data and how you can request to terminate the usage of your data.',
# 	      	linkText: 'You can find our Privacy Notice here',
# 	      	buttonText: 'Ok'
#    		},
# 	    luminaires: {
# 	    		regulationText: 'Regulation (EU) No: 874/2012',
# 	    		energyLabelling: 'Energy rating',
# 	    		compatible: 'This luminaire is compatible with bulbs of energy classes:',
# 	    		energyDeclaration: 'ENERGY RATING',
# 	    		imageNumber: '874/2012'
#
# 	   	},
#     	turnTo: {
# 		    labels: {
# 		    	reviewesLabel: "REVIEWS",
# 		    	finishReview: "FINISH THIS REVIEW",
# 		    	submitReviewCTA: "Send my review",
# 		    	helpHeading: "Help us rate your latest purchase",
# 		    	greeting: "HI",
# 		    	shareExperienceCta: "Share your experience",
# 		    	shareExperienceCtaText: "and help others make great  decisions, please rate your latest purchase",
# 		    	productSatHeading: "Product satisfaction",
# 		    	productSatText: "Rate your product satisfaction",
# 		    	ratingHeading: "Rating",
# 		    	sizeFitHeading: "SIZE AND FIT",
# 		    	myProfileHeading: "My profile",
# 		    	myProfileText: "Help others make great decisions, tell them a little about yourself.",
# 		    	reviewTextLong: "What do you think? People talk about quality, look and feel.",
# 		    	thankYouHeading: "THANK YOU!",
# 		    	thankYouText: "Your feedback is much appreciated",
# 		    	moreReviewCta: "Your reviews are really valuable",
# 		    	moreReviewCta2: "Let&#039;s go for another one!",
# 		    	othersLabel: "What other customers think based on",
# 		    	numberReviews: "{xx} reviews",
# 		    	numberReviewsMenu: "Reviews ({xx})",
# 		    	numberComments: "{xx} comments",
# 		    	othersHeading: "WHAT OTHER CUSTOMERS THINK",
# 		    	userProfileShort: 'in size {size}',
# 		    	commentTitle: 'COMMENT',
# 		    	commentText: 'What do you think? People talk about quality, look and feel.',
# 		    	basedText: "Based on",
# 		    	customerReviews: "customer reviews",
# 		    	boughtLabel: "Bought:",
# 		    	inSizeLabel: "in size",
# 		    	aboutMeLabel: "About me:",
# 		    	showMoreLabel: "Show more",
# 		    	selectedBodyType: "{bodyType} body type",
# 		    	selectedSkinTone: "[skynTone]",
# 		    	selectedSkinType: "{skinType} skin type",
# 		    	filterLabel: "[filter]",
# 		    	sortByLabel: "Sort by",
# 		    	sortOptionLables: [
# 		    		"Most Relevant",
# 		    		"Newest",
# 		    		"Highest Rated",
# 		    		"Lowest Rated"
# 		    	],
# 		    	reviewsDescriptionLabel: "[reviewDescription]",
# 		    	clearAllCta: "[clearAll]",
# 		    	noReviewesHeading: "[noMatchReview]",
# 		    	noReviewesText: "[noReviewText]",
# 		    	colorPurchased: "[purchasedColor]",
# 		    	sizePurchased: "[pushasedSize]",
# 		    	heightLabel: "Height",
# 		    	bodyTypeLabel: "[bodyTypeLabel]",
# 		    	skinToneLabel: "[skinToneLabel]",
# 		    	SkinTypeLabel: "[skinTypeLabel]",
# 		    	labelAll: "All",
# 		    	doneCta: "[done]",
# 		    	clearCta: "[clear]",
# 		    	backCta: "Back",
# 		    	unreviewedItemsPlaceholder: "Your purchased items will show up here, waiting for your review.",
# 		    	unreviewedItemsText: "Let&#039;s leave a review!",
# 		    	itmesCount: "{x} items",
# 		    	leaveReviewCta: "Leave a Review",
# 		    	gotohm: "Go to HM.com",
# 		    	reviewHeading: "REVIEW",
# 		    	shareThoughtsHeading: "SHARE YOUR THOUGHTS ON THIS ITEM!",
# 		    	dimensionText: "What do you think? People talk  about style, occasion and feel.",
# 		    	ratingValidationText: "Your review must include a rating.",
# 		    	maxLengthValidationText: "We&#039;d love to hear your full review, but we&#039;re limited to 5000 characters. Please shorten to post!",
# 		    	unfinishedReviewHeading: "Your review means a lot.",
# 		    	unfinishedReviewtext: "Please finish before you leave. Your changes will not be saved.",
# 		    	unfinishedReviewCta: "Yes, I want to finish",
# 		    	unfinishedReviewExit: "EXIT",
# 		    	shopNowLabel: "SHOP NOW",
# 		    	ratingStarTips: [
# 			    	'Poor',
# 			    	'Fair',
# 			    	'Average',
# 			    	'Good',
# 			    	'Excellent'
# 			    ],
# 			    myhmReviewSection: {
# 		    		noReviewText: 'Your purchased items will show up here, waiting for your review.',
# 				    canReviewText: 'You have {xx} item(s) waiting for your opinion.',
# 					errorText: 'Server error, please try again later.'
# 	        	},
# 			    headlines: {
# 			    	normal: {
# 			    	  title: "REVIEWS",
# 			    	  subTitle: "Tell us what you thought of these items"
# 			    	  },
# 			    	validationError: {
# 			    	  title: "ALMOST THERE!",
# 			    	  subTitle: "Please take a look at what is missing to continue:",
# 			    	  text:  "1. Add rating. 2. Tick Terms of Use box."
# 			    	},
# 			    	connectionError: {
# 			    	  title: "OH, SNAP!",
# 			    	  subTitle: "It looks like you can&#039;t review right now. Please try again later. Thanks for your patience!",
# 			    	  text:  "In the meanwile, head over to our shop!"
# 			    	},
# 			    	NotLoggedIn: {
# 			    	  title: "THANK YOU!",
# 			    	  subTitle: "Your reviews are really valuable",
# 			    	  text:  ""
# 			    	},
# 			    	reviewFiltersError: {
# 			    	  title: "Sorry",
# 			    	  text: "We could not show any comments about this item at the moment. Please try again in a little while."
# 			    	},
# 			    	oldPurchasedProduct: {
# 			    	  title: "Sorry",
# 			    	  subTitle: "Products were purchased more than {x} days ago and cannot be reviewed.",
# 			    	  text: "However, you can still review below other items that you have bought."
# 			    	},
# 			    	reviewError: {
# 			    	  title: "HI AGAIN!",
# 			    	  subTitle: "YOU HAVE ALREADY REVIEWED THIS ITEM.",
# 			    	  text1: "However, you can still review other items that you have bought below.",
# 			    	  text2: "However, you can always head over to our shop to see what&#039;s trending right now!"
# 			    	},
# 			    	start: {
# 			    	  title: "THANK YOU!",
# 			    	  subTitle: "Your reviews are really valuable",
# 			    	},
# 			    	end: {
# 			    	  title: "YOU&#039;RE THE BEST!",
# 			    	  subTitle: "Your reviews are very valuable",
# 			    	},
# 			    	random: [
# 			    	  "THE MORE THE BETTER!",
# 			    	  "JUST ONE MORE!",
# 			    	  "YES, THIS IS AWESOME!",
# 			    	  "YOU&#039;RE ON A ROLL",
# 			    	  "FLAWLESS!",
# 			    	  "YOU RISE AND SHINE!",
# 			    	  "MORE IS ALWAYS MORE, THANK YOU!",
# 			    	  "DIAMONDS, YOU KEEP ON GIVING!",
# 			    	]
# 	    		},
# 	    		 pointsCommunication: {
# 	                 nonLoggedIn: {
# 	                     copy1: "If you are a member, your points will be awarded if and when your review is published.",
# 	                     copy2: "If you are a member, your points will be awarded if and when your review is published. Not a member yet?{URL} Join now!{/URL}",
# 	                     modalURL: 'join'
# 	                 },
# 	                 clubMember: {
# 	                     copy1: "You&#039;ll earn 0 Points for each item you review — up to 0 products per month.",
# 	                     copy2: "Your points will be awarded if and when your review is published.",
# 	                     copy3: "You&#039;ll earn points for every review!",
# 	                     copy4: "Your points will be awarded if and when your review is published."
# 	                 },
# 	                 nonClubMember: {
# 	                     copy1: "If you {URL}become a member{/URL}, you can earn points when you review an item — collect enough points and you&#039;ll receive a bonus to use for future purchases.",
# 	                     copy2: "Don&#039;t forget to {URL}become a Loyalty Member{/URL} — you can earn points for leaving reviews! Collect enough points and you&#039;ll receive a reward to use on future purchases!",
# 	                     copy3: "Did you know Members earn points for product reviews and get exclusive offers and rewards? Join now, it’s free!",
# 	                     copy4: "Become a member",
# 	                     modalURL: 'club-upgrade'
# 	                 }
# 	             },
# 		    	continueShoppingBtn: {
# 			    	text: "Continue Shopping",
#                     urlLink: "/en_us/index.html"
# 			    },
# 			    joinClubBtn: {
# 			        text: "Become a member",
# 			        remodalTriggerId: "club-upgrade"
# 			    },
#     		},
# 		    showMoreBtn: {
# 	        	text: "Show More Products"
# 	      	}
#     	},
#     	notifyIfBack: {
#     		notifyMeButton: 'NOTIFY ME',
#     		notifyMeList: 'Notify me',
#     		notifyMeListMessage: 'Get notified when your size is back.',
# 	        outOfStock: 'Out of stock',
# 	        moveToBag: '[moveToBag]',
# 	        modal: {
# 	          select: {
# 	            heading: 'KEEP ME POSTED',
# 	            info: 'If your product comes back in stock, we&#039;ll email you.',
# 	            pickSize: 'Size',
# 	            selectSize: 'Select size',
# 	            notify: 'WE WILL NOTIFY YOU AT:',
# 	            disclaimer: 'Your request will be saved for 3 months.',
# 	            button: 'NOTIFY ME'
# 	          },
# 	          success: {
# 	            heading: 'YOU&#039;RE ALL SET',
# 	            info: 'If your product comes back in stock, we&#039;ll email you at {0}',
# 	            button: 'Continue Shopping'
# 	          },
# 	          error: {
# 	            heading: 'OH NO!',
# 	            info: 'For some reason, we couldn&#039;t register your notification request.',
# 	            button: 'TRY AGAIN'
# 	          },
# 	          login: {
# 	            heading: 'DON&#039;T MISS OUT!',
# 	            info: 'Get notified if your product comes back in stock — it&#039;s easy!',
# 	            text: 'Simply sign in and click on &#039;Notify Me&#039; and you&#039;ll receive a notification if this product comes back again.',
# 	            button: 'Sign in / join'
# 	          }
# 	        }
# 	      },
# 		video: {
# 			'playButtonText' : 'Play video',
# 			'pauseButtonText' : 'Pause video',
# 			'closeButtonText' : 'Close video',
# 			'videoErrorTitle' : 'Oops!',
# 			'videoErrorText' : 'Seems like we&#039;re having trouble loading this video',
# 			'videoReloadText' : 'Reload',
# 			'videoLoadingText' : 'Video player is loading now'
# 		},
#     	searchImgAlt: {
# 	    	washTag: 'Wash Tag',
# 	    	priceTag: 'Price Tag'
#     	},
#     	confirm: 'OK',
# 	    general: {
# 	    	next: 'Next',
# 	    	previous: 'Previous',
# 	    	close: 'Close',
# 	    	all: 'All',
# 	    	enableContrastMode: 'Enable high-contrast mode',
# 	    	disableContrastMode: 'Disable high-contrast mode',
# 	    	hm: 'H&amp;M',
# 	    	hennes: 'Hennes &amp; Mauritz'
#     	},
#     	pdp: {
# 	    	artNo: 'Art. No.',
# 	    	soldOut: 'Sold out',
# 	    	fewPiecesLeft: 'Few pieces left',
# 	    	comingSoon: 'Coming soon',
# 	    	comingSoonButton: 'COMING SOON'
#     	},
#     	product: {
#     		newArrivalText: 'New Arrival'
#     	},
#     	completeRegistration: '[pleaseCompleteRegistration]',
#         giftCard: {
#         	servicedown: 'Service Down'
#         },
#         sustainability: {
#             starterButton: 'PRODUCT BACKGROUND',
#             modalTitle: 'PRODUCT BACKGROUND',
#             introText: 'We believe that greater transparency will help lead the change towards a more sustainable future. As a step in this long-term commitment, we’re sharing how and where our products are made wherever possible. ',
#             introTextNoSuppliers: 'We believe that greater transparency will help lead the change towards a more sustainable fashion future. As a first step in this long-term commitment, we’re sharing how our products are made wherever possible.',
#             materials: {
#               headerText: 'MATERIALS',
#               bodyText: 'Our goal is to use 100% recycled or other sustainably sourced materials by 2030.'
#             },
#             suppliers: {
#               headerText: 'OUR SUPPLIERS',
#               backText: "Back",
#               bodyTextCountryList: 'This product has been produced in one of the following countries:',
#               buttonSeeAllText: 'Suppliers and factories for this product.',
#               introText: 'All of our products are made by independent suppliers, often in developing countries where our presence can make a real difference. Our business helps to create jobs and independence, particularly for women — consequently lifting people out of poverty and contributing to economic growth.   We only work with partners who share our respect for people and the environment, and who are willing to work with us to improve their practices. All suppliers and factories must sign our strict Sustainability Commitment, which includes requirements for fair wages and good working conditions for all. We employ a dedicated sustainability staff in our worldwide production offices to make sure the commitment is followed.',
#               sorryText: 'Unfortunately, supplier and factory information isn’t currently available for this product. Thank you for being patient while we work towards displaying these details for all H&amp;M items possible.',
#               modalTitle: 'SUPPPLIER &amp; FACTORY LIST',
#               workersAmount: 'Number of workers:',
#               disclaimerTop: 'These suppliers and factories made this product for H&amp;M globally, which means that the item you will receive is produced by one of these suppliers and one of their factories.',
#               disclaimerLabelsupplierAndFactoryExplanationText: 'We want to be completely transparent with you about how and where our products are made, therefore we have a new system for this.',
#               disclaimerLabelsupplierAndFactoryExplanationText_2: 'However, if an item was produced before we started using our new system, all of the supplier information may not be available. We’re focusing our efforts on making sure all items going forward, display all supplier details.',
#               disclaimerLabelsupplierAndFactoryExplanationText_3: 'If we stop working with a supplier or factory, we’ll only display the last information that we had at the point of collaboration.',
#               disclaimerLabelsupplierAndFactoryExplanationText_4: 'Thank you for bearing with us while we work towards greater transparency.'
#             },
#             fashionRecycler: {
#               headerText: 'BE A FASHION RECYCLER!',
#               bodyText: 'You too can help the environment and make fashion more sustainable. Bring unwanted clothes or home textiles to any H&amp;M store and they will be reworn, reused or recycled.'
#             }
#           },
#         strength: {
#         	bad: 'Weak',
#        		medium: 'Good',
#         	strong: 'Strong'
#         }
#    	};
#     hm.options.passwordStrengthScript = {
#     		enabled: true,
#             urlPath: 'https://cdnjs.cloudflare.com/ajax/libs/zxcvbn/4.2.0/zxcvbn.js'
# 	};
#  hm.options.vkAppId = '5104831';
#  hm.options.baiduKey = 'swDgGnUXEsDc69fssH1PiFdMy0pqsq4y';
#  hm.options.rimd = {
# 		service: 'https://lp2.hm.com/hmgoepprod?set=width[{width}],quality[{quality}],options[limit]&source=url[{path}]&scale=width[global.width],height[15000],options[global.options]&sink=format[{ext}],quality[global.quality]',
# 		product: 'https://lp2.hm.com/hmgoepprod?source=url[{path}]&scale=width[{width}],height[{height}],options[{scale}]&sink=format[jpeg],quality[{quality}]&hmver={version}',
# 		serviceOverride: {
# 			gif: 'https://lp2.hm.com/hmgoepprod?source=url[{path}]&optimize&sink=format[{ext}]'
# 		}
# 	};
#  hm.options.googleMapApiKey = 'gme-hmhennesmauritzab';
#
#  hm.options.searchNumGuide = {
#  	    washTagImg: '/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/images/tag-wash.svg',
#  	    pricetagImg: '/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/images/tag-price.svg'
#  };
#
#  hm.options.turnTo = {
# 		  enabled: true,
#  	      dateFrom: '56',
#  	      ugcSummary: '/en_us/reviews/rrs/ugcsummary',
# 		  unreviewedPurchases: '/en_us/reviews/rrs/unreviewed',
# 	      reviewList: '/en_us/reviews/rrs/reviews',
# 	      createReview: '/en_us/reviews/rrs/createreview',
# 	      reviewFormSubmission: '/en_us/reviews/rrs/formsubmission',
#
#  	      	dimensionId: 1,
#
#  	      legal: [
#             {
#             	label: 'I accept {URL1}terms and conditions{/URL}',
#                 url1: '/en_us/customer-service/legal-and-privacy/reviews-terms-and-conditions.modal.html',
#              	validationText: "Please accept the terms and conditions to continue.",
#             	finePrint: 'The information you provide will be handled in accordance with our {URL2}Privacy notice{/URL}',
#                 url2: '/en_us/customer-service/legal-and-privacy/privacy-link.modal.html'
#             }
#  	      ]
#  	  };
#
# hm.options.notifyIfBack = {
# 	enabled : true,
# 	apiUrl: 'https://nib.hm.com/api/Notify'
# };
#
# hm.options.hideUnavailableSizes = false;
#
# hm.options.video = {
# 	'accountId' : '5985631876001',
# 	'playerId' : 'aKLjzHnEl'
# };
#
# hm.options.sizeSelectorMessage = {
# 	'sizeSelectorMessageFlag': 'true',
# 	'sizeScaleCodes': '270~271~272',
# 	'sizeSelectorMessage': 'We’ve removed half sizes in shoes. Please see our Size Guide for updates.~We’ve removed half sizes in shoes. Please see our Size Guide for updates.~We’ve removed half sizes in shoes. Please see our Size Guide for updates.'
# };
#
# hm.options.sizeGuideTooltipMessage = {
# 	'sizeGuideTooltipFlag': 'false',
# 	'sizeGuideTooltipMessage': ''
# };
#
#  hm.options.trendingSearches = {
#     url: '/en_us/pra/panel/top-searches',
#     errorTitle: '[trendingErrorTitle]'
#   };
#
#  hm.options.ugc = {enabled: true};
#
#  hm.options.isPublishMode = true;
#
#
#  hm.options.preshopperData = {
# 	bookingsService: '/en_us/loyalty/booking/bookings',
# 	memberService: '/en_us/loyalty/getMember',
# 	offersService: ''
#  };
#
#  hm.options.useNewFilter = true;
#
#  hm.options.quickBuyBaseUrl = '/en_us/productpage/_jcr_content/product.quickbuy.{{=it.articleCode}}.html';
#
#  hm.options.acceptableJoin = {};
#
#  	hm.options.acceptableJoin.popupTimes = 2;
#
#
#  hm.options.comparativePrice = true;
#
#  hm.options.sustainability = {
#          getSuppliers: '/en_us/supplierDetails/articles/'
#      }
#
#
#  $(document).ready(function(){
# 	 if(!hm.options.isPublishMode){
# 		 $('.preshopping-container').show();
# 	 }
# 	 else{
#  		$('.preshopping-container').has("article[data-preshopping-teaser=false]").show();
# 	 }
#  });
# </script><noscript>
# <div class="responsive status-message is-open notice">
# <div class="message icon icon-banner-info-white">
#   		Welcome! HM.com works best with JavaScript enabled. Turn it on and enjoy the latest fashion!
#   		</div>
# </div>
# </noscript><div class="warehousemessage"></div>
# <header class="header-global">
# <nav class="menu" ng-init="preshoppingOfferKey='';preshoppingCountdown='900000';preshoppingOfferPageUrl='';hmClubEnabled=true; timeInterval=5000; autorefreshCount=3;  offersSpace='rewardSpace'; hmClubServiceCacheDuration=0; hmRedirectPath='/en_us/account'">
# <a class="hide-content focusable" href="#main-content" title="Skip navigation">Skip navigation</a>
# <a class="menu__hm" href="/en_us/index.html">
# <span class="hide-content notranslate">HM.com</span>
# </a>
# <button class="menu__trigger js-menu-trigger">Menu</button>
# <ul class="menu__session menu__session--hidden">
# <li class="menu__session__item">
# <div class="account parbase">
# <a class="menu__myhm" data-remodal-trigger="signin" data-signin-state="guest" href="#">
# 		Sign in
# 	</a>
# <a class="menu__myhm" data-signin-state="signedin" href="/en_us/account">
# 		My Account
# 	</a>
# <div class="myhm-dropmenu" data-signin-state="guest">
# <button class="button large" data-remodal-trigger="signin">
#             Sign in
#          </button>
# <ul class="list">
# <li class="list-item">
# <a class="link" data-remodal-trigger="signin-account" href="/en_us/account">My Account</a>
# </li>
# <li class="list-item">
# <a class="link" href="/en_us/member/info.html">Loyalty Program Info</a>
# </li>
# <li class="list-item">
# <a class="link" data-remodal-trigger="join" href="#">Not a Member yet? Join here!</a>
# </li>
# </ul>
# </div>
# <div class="myhm-dropmenu" data-signin-state="signedin">
# <ul class="list">
# <li class="list-item">
# <a class="link" href="/en_us/account">My Account</a>
# </li>
# <li class="list-item">
# <a class="link" href="/en_us/member/info.html">Loyalty Program Info</a>
# </li>
# <li class="list-item">
# <a class="link" href="/en_us/logout" onclick="trackLogout()">Sign out</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="menu__session__item">
# <button class="menu__search_toggle js-search-toggle">
# <span class="hide-content">Search products</span>
# </button>
# </li>
# <li class="menu__session__item">
# <a class="menu__favorites" href="/en_us/favourites">
# 			        		Favorites</a>
# </li>
# <li class="menu__session__item shopping-bag rollover-popdown" data-cart="/en_us/minicart/view">
# <span class="minicart parbase"><a class="menu__bag goto-shopping-bag rollover-toggle" href="/en_us/cart">
# 	Shopping bag(<span class="shoppingbag-item-count">0</span>)
# </a>
# <hm-menu-mini-cart id="menu-mini-cart"></hm-menu-mini-cart>
# <script>
#     document.getElementById('menu-mini-cart').props = {
#     isOpen: false,
#     }
# </script></span>
# </li>
# </ul><!-- /Session menu -->
# <div class="autosuggestsearch parbase"><section aria-expanded="false" class="menu__search_wrapper ui-widget" id="search-field">
# <form action="/en_us/search-results.html" class="menu__search" method="get">
# <span aria-live="polite" class="ui-helper-hidden-accessible" role="status"></span>
# <input aria-label="Search products" autocomplete="off" autocorrect="off" class="ui-autocomplete-input menu__search_input" data-autocomplete-disabled="false" data-test="false" data-url="/content/hmonline/en_us/jcr:content/header/autosuggestsearch.display.html" id="main-search" maxlength="200" minlength="3" name="q" placeholder="Search products" spellcheck="false" type="search"/>
# <button class="menu__search_submit" type="submit"><span class="hide-content">Search products</span></button>
# </form>
# </section>
# </div>
# <ul class="menu__primary"><!-- Primary menu -->
# <li class="menu__sign-in">
# <a class="menu__sign-in-button" data-remodal-trigger="signin" data-signin-state="guest" href="#">Sign in</a>
# <a class="menu__sign-in-button" data-signin-state="signedin" href="/en_us/account">My Account</a>
# </li>
# <li class="menu__super menu__super--has-sub js-traverse-trigger">
# <a class="menu__super-link" data-deparment-toggle-text="Toggle submenu for the Women deparment" data-goto-text="Go to Women home" href="/en_us/women.html">
# <span>Women</span>
# </a>
# <button class="menu__accessibility-trigger" style="padding:0">
# <span class="hide-content">Toggle submenu for the Women deparment</span>
# </button>
# <ul class="menu__sub">
# ...
# <div class="item"><a class="link" href="/en_us/men.html">Men</a></div>
# <div class="item"><a class="link" href="/en_us/baby.html">Baby</a></div>
# <div class="item"><a class="link" href="/en_us/kids.html">Kids</a></div>
# <div class="item"><a class="link" href="/en_us/home.html">H&amp;M HOME</a></div>
# <div class="item"><a class="link" href="/en_us/unidays.html">Student Discount</a></div>
# </div>
# </nav>
# <nav class="footer-category"><h4 class="footer-heading">
# <button class="js-toggle-trigger toggle-button">CORPORATE INFO</button>
# </h4>
# <div class="list">
# <div class="item"><a class="link" href="https://career.hm.com/content/hmcareer/en_us.html" target="_blank">Career at H&amp;M</a></div>
# <div class="item"><a class="link" href="https://hmgroup.com/about-us.html" target="_blank">About H&amp;M</a></div>
# <div class="item"><a class="link" href="https://hmgroup.com/sustainability.html" target="_blank">Sustainability</a></div>
# <div class="item"><a class="link" href="https://about.hm.com/" target="_blank">Press</a></div>
# <div class="item"><a class="link" href="https://hmgroup.com/investors.html" target="_blank">Investor Relations</a></div>
# <div class="item"><a class="link" href="https://hmgroup.com/about-us/corporate-governance.html" target="_blank">Corporate Governance</a></div>
# </div>
# </nav>
# <nav class="footer-category"><h4 class="footer-heading">
# <button class="js-toggle-trigger toggle-button">HELP</button>
# </h4>
# <div class="list">
# <div class="item"><a class="link" href="/en_us/customer-service.html">Customer Service</a></div>
# <div class="item"><a class="link" href="http://www2.hm.com/en_us/login">My Account</a></div>
# <div class="item"><a class="link" href="/en_us/customer-service/shopping-at-hm/store-locator.html">Find a Store</a></div>
# <div class="item"><a class="link" href="/en_us/customer-service/legal-and-privacy.html">Legal &amp; Privacy</a></div>
# <div class="item"><a class="link" href="/en_us/customer-service/contact.html">Contact</a></div>
# <div class="item"><a class="link" href="/en_us/customer-service/gift-card.html">Gift Card</a></div>
# <div class="item"><a class="link" href="https://www.hm.com/us/customer-service/ca-supply-chains-act">CA Supply Chains Act</a></div>
# <div class="item"><a class="link" href="/en_us/customer-service/legal-and-privacy/california-privacy-rights.html">California, Colorado, and Virginia Privacy Rights</a></div>
# <div class="item"><a class="link" href="/en_us/customer-service/legal-and-privacy/do-not-sell-ca.html">Do Not Sell My Personal Information</a></div>
# <button class="ot-sdk-show-settings link" id="ot-sdk-btn">Cookie Settings</button>
# </div>
# </nav>
# <section class="footer-newsletter">
# <div class="newsletter newslettersignupform parbase"><h4 class="footer-heading">Become a member</h4>
# <p class="text">Join now and get 10% off your next purchase!</p>
# <a class="button" href="/en_us/member/info.html">READ MORE</a></div>
# </section>
# </div>
# <ul class="footer-social footer-content">
# <li class="item">
# <a class="hidden-text icon icon-social-facebook-white" href="https://www.facebook.com/hmtheus" rel="noopener noreferrer" target="_blank" title="Facebook">
# 			Facebook</a></li>
# <li class="item">
# <a class="hidden-text icon icon-social-twitter-white" href="https://twitter.com/hmusa" rel="noopener noreferrer" target="_blank" title="Twitter">
# 			Twitter</a>
# </li>
# <li class="item">
# <a class="hidden-text icon icon-social-instagram-white" href="https://www.instagram.com/hm/" rel="noopener noreferrer" target="_blank" title="Instagram">
# 			Instagram</a>
# </li>
# <li class="item">
# <a class="hidden-text icon icon-social-youtube-white" href="http://www.youtube.com/user/hennesandmauritz" rel="noopener noreferrer" target="_blank" title="Youtube">
# 			Youtube</a>
# </li>
# <li class="item">
# <a class="hidden-text icon icon-social-pinterest-white" href="https://www.pinterest.com/hm/" rel="noopener noreferrer" target="_blank" title="Pinterest">
# 				Pinterest</a>
# </li>
# </ul>
# <div class="footer-copyright footer-content">
# <p class="text js-footer-truncate">
# 			The content of this site is copyright-protected and is the property of H&amp;M Hennes &amp; Mauritz AB. H&amp;M is committed to accessibility. That commitment means H&amp;M embraces WCAG guidelines and supports assistive technologies such as screen readers.  If you are using a screen reader, magnifier, or other assistive technologies and are experiencing difficulties using this website, please call our TOLL-FREE support line (855-466-7467) for assistance. H&amp;M's business concept is to offer fashion and quality at the best price. H&amp;M has since it was founded in 1947 grown into one of the world's leading fashion companies.</p>
# <button aria-hidden="false" class="js-footer-more link" data-read-less-label="READ  LESS">READ MORE</button>
# </div>
# <a class="footer-logotype icon icon-hm-white hidden-text" href="/en_us/index.html">H&amp;M</a>
# <div class="country-info"><div class="countrylanguage parbase"><a class="country-name overlay-trigger" data-layout="confirm" data-modal-scrollup="false" href="/en_us/_jcr_content/footer/locationlanguage.changelocation.html">United States</a> | $</div>
# </div>
# <div data-remodal-content-id="signin" data-remodal-options="popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/en_us/_jcr_content/loginform.modal.html, additionalClasses: club-modal-forms">
# </div>
# <div data-remodal-content-id="signin-account" data-remodal-options="popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/en_us/_jcr_content/loginform.modal.account.html, additionalClasses: club-modal-forms">
# </div>
# <div data-remodal-content-id="join" data-remodal-options="popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/en_us/_jcr_content/joinusform.modal.html, additionalClasses: club-modal-forms, closeAllButton: true">
# </div>
# <div class="remodal-content-wrapper" data-remodal-content-id="club-upgrade" data-remodal-options="popup: true, hashtracking: true, additionalClasses: club-modal-forms club-upgrade-form, closeAllButton: true">
# <button class="remodal-close" data-remodal-action="closeall">Close Dialog</button>
# <div class="remodal-content">
# <div class="hm-form">
# <header class="header">
# <h2 class="heading icon-hm-club-logo-light">Become a member</h2>
# <p class="excerpt">Become a Member — you'll enjoy exclusive deals, offers, invites and rewards.</p>
# </header>
# <form class="form js-form-clubjoin" method="POST" novalidate="">
# <div class="content">
# <div class="inputwrapper required">
# <div class="inputwrapper required">
# <label class="label" data-optional="(Optional)" for="club-dob">text.account.birth.date</label>
# <div class="select-date">
# <div class="merged-inputs">
# </div>
# <input class="input-date" data-format-text="text.hmClub.incorrect.format" data-min-age="16" data-min-age-text="checkout.home.address.birthdate.minage" data-show-text-after-this="true" data-validation-birthdate="true" data-validation-minlength-text="text.hmClub.dob.minimum.length" data-validation-required-text="checkout.home.address.birthdate.invalid" id="club-dob" name="birthDate" required="" type="hidden" value=""/>
# </div>
# <div class="input-info">text.hmClub.dob.required.reason</div>
# </div>
# <div class="inputwrapper full">
# <input class="checkbox-input" name="hmClubJoin" type="hidden" value="true"/>
# <input class="checkbox-input" id="upgrade-create-account-fashion-news" name="hmNewsSubscription" type="checkbox" value="true"/>
# <label class="checkbox-label" for="upgrade-create-account-fashion-news">
#                             Yes, email me my member rewards, special invites, trend alerts and more.
#                         </label>
# <p class="checkbox-description">Your inbox is about to get a lot more stylish! Get excited for exclusive deals, trend alerts, first access to our new collections, and more. Plus, don't miss out on all your Member rewards, birthday offer and special invites to events!</p>
# </div>
# <p class="text">By clicking ‘Become a member’, I agree to the H&amp;M Membership <a class="underline" data-remodal-trigger="terms-and-conditions">Terms and conditions</a>.</p>
# <p class="text">To give you the full membership experience, we will process your personal data in accordance with the H&amp;M's <a class="underline" data-remodal-trigger="privacy-notice" href="/en_us/customer-service/legal-and-privacy/privacy-notice-hm-club-link.html">Privacy Notice</a>.</p>
# <button class="button large js-submit-clubjoin" type="submit">Become a member</button>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="remodal-content-wrapper" data-remodal-content-id="terms-and-conditions-for-club" data-remodal-options="escape:false, popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/en_us/_jcr_content/clubtermsandconditions.modal.html, additionalClasses: popup-logo-header, closeButton: false">
# </div>
# <div class="globalmodals parbase">
# <div data-remodal-content-id="terms-and-conditions" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/club-terms-link.html, ajaxHTMLSelector:.article-contents, additionalClasses: popup-termsconditions">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="termsconditions-popup" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/club-terms-link.html, ajaxHTMLSelector:.article-contents, additionalClasses: popup-termsconditions">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="privacypolicy-popup" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-notice-hm-club-link.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="privacy-notice" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-notice-hm-club-link.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="privacy-policy" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-link.modal.html, ajaxHTMLSelector:.article-contents, additionalClasses: popup-privacy">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="privacy-direct-marketing" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-notice-direct-marketing-link.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# <div class="remodal-content"></div>
# </div>
# <div data-remodal-content-id="privacy-policy-fashion" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-notice-hm-account-link.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="personal-data-consent" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/consent-of-personal-data/dataprocessing.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="personal-data-overseastransfer" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/consent-of-personal-data/overseastransfer.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="hmclub-terms-and-conditions" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/h-m-club/h-m-club-terms-conditions.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <!-- Modal content for the account access   -->
# <div data-remodal-content-id="accountaccess-popup" data-remodal-options="ajaxUrl:/en_us/customer-service/dontagreepage.modal.html, popup: true, additionalClasses: account-access">
# <header class="remodal-header">
# <h2 class="heading">
# </h2>
# </header>
# <div class="remodal-content"></div>
# </div>
# </div>
# </div></footer><!-- /Footer -->
# <div class="tealiumPageviewtag pageview parbase"><script type="text/javascript">utag_data = {touchpoint : getTouchpoint() , page_id : "Men : Shopbyproduct : Jeans : Viewall", category_id : "MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL", category_path : "MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL", selected_market : "US", display_language : "en_US", event_type  : "", customer_id : "", customer_email : "", customer_zip : "", customer_city : "", customer_state : "", customer_state : "", customer_country : "", customer_loyalty_level : "", customer_has_children : "", customer_fashion_news : "" }; utagTealiumTrack(function(a,b,c,d){var forceUtagLogic = (hm.device.iPhone() && hm.options.forceUtagForIOS) || (hm.device.android() && hm.options.forceUtagForAndroid);    if(!hm.device.app() || (hm.device.app() && forceUtagLogic ) ){a=getTealiumURL("US");b=document;c='script';d=b.createElement(c);d.src=a;d.id='utagMainScript';d.type='text/java'+c;d.async=true;a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);}}); hm.Tracking.appPageView(utag_data);</script> </div>
# <div class="nuancechat nuanceChat parbase">
# <div id="Nuance-chat-anchored"></div>
# <script async="" charset="utf-8" src="https://hm-us.inq.com/chatskins/launch/inqChatLaunch10006533.js" type="text/javascript"></script>
# <script>
#   hm.waitUntil(function() {
# 		return hm.version;
# 	}).then(function() {
# 		hm.cookies = hm.cookies || new hm.Cookies();
# 		var nuanceData={};
# 		window.nuanceData = nuanceData;
# 		if(hm.cookies && hm.cookies.readCookie('userCookie')){
# 			var userCookieVal = JSON.parse(hm.cookies.readCookie('userCookie'));
# 			if (userCookieVal){
#
# 				if(userCookieVal.cartCount>=0){
# 					nuanceData["cartCount"] = userCookieVal.cartCount;
# 				}
# 			if(userCookieVal.dominantCategory){
# 					nuanceData["dominantCategory"] = userCookieVal.dominantCategory;
# 				}
# 				if(userCookieVal.cartProducts){
# 					nuanceData["cartProducts"] = userCookieVal.cartProducts;
# 				}
# 				if(userCookieVal.hybris_firstName){
# 					nuanceData["hybris_firstName"] = decodeURIComponent((userCookieVal.hybris_firstName + '').replace(/\+/g, '%20'));
# 				}
# 				if(userCookieVal.hybris_uuid){
# 					nuanceData["hybris_uuid"] = userCookieVal.hybris_uuid;
# 				}
# 				if(userCookieVal.customer_id){
# 					nuanceData["customer_id"] = userCookieVal.customer_id;
# 				}
# 				if(userCookieVal.type){
# 					nuanceData["type"] = userCookieVal.type;
# 				}
# 				if(userCookieVal.str){
# 					nuanceData["st"] = decodeURIComponent(userCookieVal.str.replaceAll(/\+/g, ' '));
# 				}
# 				if(userCookieVal.zc){
# 					var val = userCookieVal.zc.replace(/[+,-]/g," ");
# 						nuanceData["zc"] = val;
# 			}
# 				if(userCookieVal.tn){
# 					nuanceData["tn"] = decodeURIComponent(userCookieVal.tn.replaceAll(/\+/g, ' '));
# 				}
# 			}
# 		}
# 		var favouritesCookie = hm.options.product.country + "-favourites";
#
# 		var hasFav = hm.cookies.readCookie("hm-austria-favourites");
# 		if(hasFav && !(hasFav==="\"\"")){nuanceData["hm-country-favourites"] = hasFav;}
# 		console.log(nuanceData);
# 	});
# 	</script>
# <script type="text/javascript">
# 		// Click on Chat icon
# 		$(document).on("click", "#Nuance-chat-anchored", function() {
# 			hm.Tracking.link({
# 				event_type : 'AI_CHAT_INITIATE',
# 				event_id : 'Click on Start AI chat',
# 				event_category : 'AI Chat',
# 				event_label : hm.options.tealiumPageId
# 			});
#
# 			console.log(document.URL);
# 		});
# 	</script>
# </div>
# <script src="/UO0KYkahNvLe5l4zTw/9c7zcQ6DNOVY/Bj4tAQ/RkYCa2/NiWXw" type="text/javascript"></script></body></html>

# %%
products = soup.find('ul', 'products-listing small')

# %%
products
# Out:
# <ul class="products-listing small">
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256001" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDFfZW5fdXM7MTAyNDI1NjAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1024256001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256001.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/77/b5/77b566ce3845791ecb47a6252b6c1e16fd93ea68.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/00/0b/000b5d6009a7bd05a76a9ec22f8bd784f4b2271a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/00/0b/000b5d6009a7bd05a76a9ec22f8bd784f4b2271a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256001|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256001.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256005.html" style="background-color: #2F323B" title="Dark blue">
# 				Dark blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256003" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDNfZW5fdXM7MTAyNDI1NjAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1024256003');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256003.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/e3/e8/e3e81b8bc860bd9ba65e2940d0a7c9635d42cc66.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/3d/02/3d02a6f6f9f2ad047ec29a36738bb00251e3d110.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/3d/02/3d02a6f6f9f2ad047ec29a36738bb00251e3d110.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256003|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256003.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256005.html" style="background-color: #2F323B" title="Dark blue">
# 				Dark blue</a></li>
# </ul><div class="new-product">New Arrival</div>
# </div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0690449056" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449056'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wNTZfZW5fdXM7MDY5MDQ0OTA1Nl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0690449056');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0690449056.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/f4/72/f472300fb43decf6dcffaece4e2c3249073615e3.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/a0/89/a0893b6c257f601d3714eb7e3e874a22f45bd3f3.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/a0/89/a0893b6c257f601d3714eb7e3e874a22f45bd3f3.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449056|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0690449056.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 39.99</span>
# </strong><ul class="list-swatches" data-swatches-total="5">
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449056.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
# 				Black/trashed</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449036.html" style="background-color: #303033" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
# 				Light denim blue/trashed</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985159001" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDFfZW5fdXM7MDk4NTE1OTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0985159001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985159001.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/28/f0/28f0649eb24faedfb7baf756d9cc7b86f31e37de.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/13/54/1354f728b411fbb39957a24571920980962a3039.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/13/54/1354f728b411fbb39957a24571920980962a3039.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159001|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985159001.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 24.99</span>
# </strong><ul class="list-swatches" data-swatches-total="7">
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
# 				Dark blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0690449022" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449022'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wMjJfZW5fdXM7MDY5MDQ0OTAyMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0690449022');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0690449022.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/dc/be/dcbec7b58345a0f1defb8ea12a7b83724e0ea8d1.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/4f/6c/4f6c55c159d3b66a063f59b1de087237817ea4e4.jpg],origin[dam],category[men_jeans_skinny],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449022|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0690449022.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 39.99</span>
# </strong><ul class="list-swatches" data-swatches-total="5">
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
# 				Black/trashed</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449036.html" style="background-color: #303033" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
# 				Light denim blue/trashed</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449051.html" style="background-color: #94989F" title="Gray">
# 				Gray</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256004" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256004'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDRfZW5fdXM7MTAyNDI1NjAwNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1024256004');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256004.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/79/34/7934a8d7525532547dfef00416aba449e58493d1.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/de/0d/de0de85e67d02b69bebeddd2c67d1aad03e95505.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256004|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256004.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256005.html" style="background-color: #2F323B" title="Dark blue">
# 				Dark blue</a></li>
# </ul><div class="new-product">New Arrival</div>
# </div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256007" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256007'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDdfZW5fdXM7MTAyNDI1NjAwN19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1024256007');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256007.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/cd/7b/cd7b894fba8c32078439f442e205ef9d719e8fb0.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/79/f1/79f1635e3f59f469cfe85150dfec79e055ddf0c8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256007|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256007.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256007.html" style="background-color: #494A4F" title="Dark gray">
# 				Dark gray</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# </ul><div class="new-product">New Arrival</div>
# </div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0690449051" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449051'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wNTFfZW5fdXM7MDY5MDQ0OTA1MV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0690449051');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0690449051.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/76/92/7692f6468795a359c6dd0bcb0670ea2f9cba4f56.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/00/bb/00bb27c18ef0b3696a52a0a0a38105fdb63335df.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449051|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0690449051.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 39.99</span>
# </strong><ul class="list-swatches" data-swatches-total="5">
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449051.html" style="background-color: #94989F" title="Gray">
# 				Gray</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
# 				Black/trashed</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449036.html" style="background-color: #303033" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
# 				Light denim blue/trashed</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0690449043" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449043'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wNDNfZW5fdXM7MDY5MDQ0OTA0M19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0690449043');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0690449043.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/76/e2/76e23bc5c3d3110fd5050a8536728e87b517b01d.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/51/e4/51e42a38e1b2985a3eebe23604ffdb5a934c707e.jpg],origin[dam],category[men_jeans_skinny],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449043|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0690449043.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 39.99</span>
# </strong><ul class="list-swatches" data-swatches-total="5">
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
# 				Light denim blue/trashed</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
# 				Black/trashed</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449036.html" style="background-color: #303033" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449051.html" style="background-color: #94989F" title="Gray">
# 				Gray</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0690449036" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449036'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wMzZfZW5fdXM7MDY5MDQ0OTAzNl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0690449036');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0690449036.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/58/55/585510d7cd43eb1dd87c268941451a30290e5705.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/25/2a/252a1c07c0470db4d52fd911587e4df7c43170e9.jpg],origin[dam],category[men_jeans_skinny],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449036|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0690449036.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 39.99</span>
# </strong><ul class="list-swatches" data-swatches-total="5">
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449036.html" style="background-color: #303033" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
# 				Black/trashed</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
# 				Light denim blue/trashed</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449051.html" style="background-color: #94989F" title="Gray">
# 				Gray</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0875105016" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0875105016'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDg3NTEwNV9ncm91cF8wMTZfZW5fdXM7MDg3NTEwNTAxNl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0875105016');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0875105016.html" title="Relaxed Jeans">
# <img alt="Relaxed JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/a8/b9/a8b924ac35b9e29b573741dbe8459cfb004e70ef.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/42/e6/42e6e5b5479635f5b845d1963ebd69453945cd49.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0875105016|Relaxed Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0875105016.html">Relaxed Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 34.99</span>
# </strong><ul class="list-swatches" data-swatches-total="5">
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105016.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105017.html" style="background-color: #54586D" title="Dark denim blue">
# 				Dark denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105018.html" style="background-color: #ADBAD1" title="Pale denim blue">
# 				Pale denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105023.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# </ul><div class="new-product">New Arrival</div>
# </div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1013317001" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1013317001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAxMzMxN19ncm91cF8wMDFfZW5fdXM7MTAxMzMxNzAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1013317001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1013317001.html" title="Hybrid Regular Tapered Joggers">
# <img alt="Hybrid Regular Tapered JoggersModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/82/9b/829b20c3ed1399fc081c90ef2bcf76233943e044.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Hybrid Regular Tapered Joggers" data-src="//lp2.hm.com/hmgoepprod?set=source[/da/8f/da8f697b18f361d7226d09bacad42abbb3fba1be.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <div class="promotion-marker" data-tooltip="">
# 				Sustainable Denim</div>
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1013317001|Hybrid Regular Tapered Joggers|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1013317001.html">Hybrid Regular Tapered Joggers</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 39.99</span>
# </strong><ul class="list-swatches" data-swatches-total="7">
# <li class="item"><a class="swatch" href="/en_us/productpage.1013317001.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1013317002.html" style="background-color: #6089C2" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1013317004.html" style="background-color: #2E2E30" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1013317005.html" style="background-color: #494A4F" title="Dark gray">
# 				Dark gray</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1004199005" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199005'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDVfZW5fdXM7MTAwNDE5OTAwNV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1004199005');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1004199005.html" title="Skinny Cropped Jeans">
# <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/12/fc/12fc4fd95048b7233754de41a3c2252fa01b7ca1.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/4a/6e/4a6e5dcbafa8c5da31a3e8b1600aceb4c289ef3a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199005|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1004199005.html">Skinny Cropped Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 29.99</span>
# </strong><ul class="list-swatches" data-swatches-total="4">
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199005.html" style="background-color: #94989F" title="Light gray">
# 				Light gray</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199003.html" style="background-color: #79829D" title="Denim blue">
# 				Denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985159004" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159004'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDRfZW5fdXM7MDk4NTE1OTAwNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0985159004');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985159004.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/e0/cd/e0cd1f7369528e3fd0e1fef3c0a3a1990f06ad87.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/d4/a1/d4a1bdd9d723a874932454e854d6cc5bda5ef688.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159004|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985159004.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 24.99</span>
# </strong><ul class="list-swatches" data-swatches-total="7">
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
# 				Dark blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0875105023" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0875105023'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDg3NTEwNV9ncm91cF8wMjNfZW5fdXM7MDg3NTEwNTAyM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0875105023');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0875105023.html" title="Relaxed Jeans">
# <img alt="Relaxed JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/39/46/3946e40e7e45c05219c096431ae2eab6435303fe.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/bd/97/bd97d5e5e4b716a0a2ac10369d4ceb5f12500700.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0875105023|Relaxed Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0875105023.html">Relaxed Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 34.99</span>
# </strong><ul class="list-swatches" data-swatches-total="5">
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105023.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105016.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105017.html" style="background-color: #54586D" title="Dark denim blue">
# 				Dark denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105018.html" style="background-color: #ADBAD1" title="Pale denim blue">
# 				Pale denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985159005" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159005'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDVfZW5fdXM7MDk4NTE1OTAwNV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0985159005');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985159005.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/1f/cc/1fcc801708d85fa6181473072380341c9c1bd219.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/0b/6b/0b6b7a9dc7904561d604839e7cb63f541a37499c.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159005|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985159005.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 24.99</span>
# </strong><ul class="list-swatches" data-swatches-total="7">
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
# 				Dark blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1008110001" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008110001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODExMF9ncm91cF8wMDFfZW5fdXM7MTAwODExMDAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1008110001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1008110001.html" title="Freefit® Slim Jeans">
# <img alt="Freefit® Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/3e/8e/3e8e2a02e8951f324e47e8b161285d9fcca8ef83.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Freefit® Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/d4/bf/d4bffdc6ee3a201aefea4020ce97aead158b76c8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008110001|Freefit® Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1008110001.html">Freefit® Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 59.99</span>
# </strong><ul class="list-swatches" data-swatches-total="3">
# <li class="item"><a class="swatch" href="/en_us/productpage.1008110001.html" style="background-color: #4C5164" title="Dark denim blue">
# 				Dark denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008110002.html" style="background-color: #272628" title="Black/No fade black">
# 				Black/No fade black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008110003.html" style="background-color: #79829D" title="Light denim blue">
# 				Light denim blue</a></li>
# </ul><div class="new-product">New Arrival</div>
# </div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1004199002" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDJfZW5fdXM7MTAwNDE5OTAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1004199002');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1004199002.html" title="Skinny Cropped Jeans">
# <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/95/fe/95fe0c8d937eed977512d685f7ab8b2d64464a6d.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/f0/32/f0326127d6dd4265f1fe4a42e590ed7b19241231.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199002|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1004199002.html">Skinny Cropped Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 29.99</span>
# </strong><ul class="list-swatches" data-swatches-total="4">
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199003.html" style="background-color: #79829D" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199005.html" style="background-color: #94989F" title="Light gray">
# 				Light gray</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985159008" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159008'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDhfZW5fdXM7MDk4NTE1OTAwOF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0985159008');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985159008.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/86/f7/86f7b1e25d225723055ab84afd366dd7258165ce.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/0c/4e/0c4edaab5321b378dd3481044e6b9de7530195b2.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159008|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985159008.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 24.99</span>
# </strong><ul class="list-swatches" data-swatches-total="7">
# ...
# <div class="item-buttons">
# <div class="promotion-marker" data-tooltip="">
# 				Sustainable Denim</div>
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0993887004|Hybrid Regular Denim Joggers|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0993887004.html">Hybrid Regular Denim Joggers</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 44.99</span>
# </strong><ul class="list-swatches" data-swatches-total="3">
# <li class="item"><a class="swatch" href="/en_us/productpage.0993887004.html" style="background-color: #2E2E30" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0993887001.html" style="background-color: #79829D" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0993887002.html" style="background-color: #8898AC" title="Denim blue">
# 				Denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1013317002" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1013317002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAxMzMxN19ncm91cF8wMDJfZW5fdXM7MTAxMzMxNzAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1013317002');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1013317002.html" title="Hybrid Regular Tapered Joggers">
# <img alt="Hybrid Regular Tapered JoggersModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/01/0a/010ab4b2d57b35055c5f9ba287cbbeb6b5c7343f.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Hybrid Regular Tapered Joggers" data-src="//lp2.hm.com/hmgoepprod?set=source[/ff/ce/ffce8baee35d1ee3f886fe2cf601f959a651051a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <div class="promotion-marker" data-tooltip="">
# 				Sustainable Denim</div>
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1013317002|Hybrid Regular Tapered Joggers|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1013317002.html">Hybrid Regular Tapered Joggers</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 39.99</span>
# </strong><ul class="list-swatches" data-swatches-total="7">
# <li class="item"><a class="swatch" href="/en_us/productpage.1013317002.html" style="background-color: #6089C2" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1013317001.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1013317004.html" style="background-color: #2E2E30" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1013317005.html" style="background-color: #494A4F" title="Dark gray">
# 				Dark gray</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985159002" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDJfZW5fdXM7MDk4NTE1OTAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0985159002');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985159002.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/8d/59/8d592c0d3183668187ca199ea5366e04ed6e35b6.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/83/90/83906d6c2f5c6b94e8cf9f4421412d3270c25f54.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159002|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985159002.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 24.99</span>
# </strong><ul class="list-swatches" data-swatches-total="7">
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
# 				Dark blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1028865001" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1028865001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyODg2NV9ncm91cF8wMDFfZW5fdXM7MTAyODg2NTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1028865001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1028865001.html" title="Relaxed Jeans with Embroidery Detail">
# <img alt="Relaxed Jeans with Embroidery DetailModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/2e/6c/2e6cfe32efaaf866815d8736121d7617e78b3676.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans with Embroidery Detail" data-src="//lp2.hm.com/hmgoepprod?set=source[/ad/fb/adfb0576bc1a6af818020f6b824d94e56ce26fb5.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1028865001|Relaxed Jeans with Embroidery Detail|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-collection" style="">
# 		Smiley® x H&amp;M</div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1028865001.html">Relaxed Jeans with Embroidery Detail</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 49.99</span>
# </strong><ul class="list-swatches" data-swatches-total="1">
# <li class="item"><a class="swatch" href="/en_us/productpage.1028865001.html" style="background-color: #8898AC" title="Light denim blue/Smiley®">
# 				Light denim blue/Smiley®</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0938875007" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0938875007'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDkzODg3NV9ncm91cF8wMDdfZW5fdXM7MDkzODg3NTAwN19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0938875007');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0938875007.html" title="Slim Tapered Jeans">
# <img alt="Slim Tapered JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/7d/e4/7de4fe548155af2bcf6ae85a801eb6383a196bc2.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Tapered Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/7e/7e/7e7e2ceb8c0f7564ae999b3ae1e386b99fce62e7.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0938875007|Slim Tapered Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0938875007.html">Slim Tapered Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 39.99</span>
# </strong><ul class="list-swatches" data-swatches-total="3">
# <li class="item"><a class="swatch" href="/en_us/productpage.0938875007.html" style="background-color: #2E2E30" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0938875010.html" style="background-color: #798DB2" title="Light blue">
# 				Light blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0938875014.html" style="background-color: #33363A" title="Black">
# 				Black</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1008110003" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008110003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODExMF9ncm91cF8wMDNfZW5fdXM7MTAwODExMDAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1008110003');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1008110003.html" title="Freefit® Slim Jeans">
# <img alt="Freefit® Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/bc/a2/bca288eb687e05f6bdaf839c5f6849e8fc90fef3.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Freefit® Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/c4/2d/c42d20ffb40666f502598225f3d31361476f1a78.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008110003|Freefit® Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1008110003.html">Freefit® Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 59.99</span>
# </strong><ul class="list-swatches" data-swatches-total="3">
# <li class="item"><a class="swatch" href="/en_us/productpage.1008110003.html" style="background-color: #79829D" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008110001.html" style="background-color: #4C5164" title="Dark denim blue">
# 				Dark denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008110002.html" style="background-color: #272628" title="Black/No fade black">
# 				Black/No fade black</a></li>
# </ul><div class="new-product">New Arrival</div>
# </div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985197001" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985197001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE5N19ncm91cF8wMDFfZW5fdXM7MDk4NTE5NzAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0985197001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985197001.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/b6/26/b626e8a76cc287928788b5edc8d1fa2679440a88.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/6a/6a/6a6adf7dede242a98b194fee7cc8f60e4737ae0a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985197001|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985197001.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="3">
# <li class="item"><a class="swatch" href="/en_us/productpage.0985197001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985197003.html" style="background-color: #79829D" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985197006.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# </ul></div></article></li>
# </ul>

# %%
products_list = products.find_all('article', 'hm-product-item')

# %%
products_list
# Out:
# [<article class="hm-product-item" data-articlecode="1024256001" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDFfZW5fdXM7MTAyNDI1NjAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1024256001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1024256001.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/77/b5/77b566ce3845791ecb47a6252b6c1e16fd93ea68.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/00/0b/000b5d6009a7bd05a76a9ec22f8bd784f4b2271a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/00/0b/000b5d6009a7bd05a76a9ec22f8bd784f4b2271a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256001|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1024256001.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256005.html" style="background-color: #2F323B" title="Dark blue">
#  				Dark blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1024256003" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDNfZW5fdXM7MTAyNDI1NjAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1024256003');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1024256003.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/e3/e8/e3e81b8bc860bd9ba65e2940d0a7c9635d42cc66.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/3d/02/3d02a6f6f9f2ad047ec29a36738bb00251e3d110.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/3d/02/3d02a6f6f9f2ad047ec29a36738bb00251e3d110.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256003|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1024256003.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256005.html" style="background-color: #2F323B" title="Dark blue">
#  				Dark blue</a></li>
#  </ul><div class="new-product">New Arrival</div>
#  </div></article>,
#  <article class="hm-product-item" data-articlecode="0690449056" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449056'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wNTZfZW5fdXM7MDY5MDQ0OTA1Nl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0690449056');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0690449056.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/f4/72/f472300fb43decf6dcffaece4e2c3249073615e3.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/a0/89/a0893b6c257f601d3714eb7e3e874a22f45bd3f3.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/a0/89/a0893b6c257f601d3714eb7e3e874a22f45bd3f3.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449056|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0690449056.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449056.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
#  				Black/trashed</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449036.html" style="background-color: #303033" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
#  				Light denim blue/trashed</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159001" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDFfZW5fdXM7MDk4NTE1OTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0985159001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159001.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/28/f0/28f0649eb24faedfb7baf756d9cc7b86f31e37de.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/13/54/1354f728b411fbb39957a24571920980962a3039.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/13/54/1354f728b411fbb39957a24571920980962a3039.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159001|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159001.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 24.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
#  				Dark blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0690449022" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449022'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wMjJfZW5fdXM7MDY5MDQ0OTAyMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0690449022');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0690449022.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/dc/be/dcbec7b58345a0f1defb8ea12a7b83724e0ea8d1.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/4f/6c/4f6c55c159d3b66a063f59b1de087237817ea4e4.jpg],origin[dam],category[men_jeans_skinny],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449022|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0690449022.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
#  				Black/trashed</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449036.html" style="background-color: #303033" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
#  				Light denim blue/trashed</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449051.html" style="background-color: #94989F" title="Gray">
#  				Gray</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1024256004" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256004'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDRfZW5fdXM7MTAyNDI1NjAwNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1024256004');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1024256004.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/79/34/7934a8d7525532547dfef00416aba449e58493d1.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/de/0d/de0de85e67d02b69bebeddd2c67d1aad03e95505.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256004|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1024256004.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256005.html" style="background-color: #2F323B" title="Dark blue">
#  				Dark blue</a></li>
#  </ul><div class="new-product">New Arrival</div>
#  </div></article>,
#  <article class="hm-product-item" data-articlecode="1024256007" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256007'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDdfZW5fdXM7MTAyNDI1NjAwN19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1024256007');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1024256007.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/cd/7b/cd7b894fba8c32078439f442e205ef9d719e8fb0.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/79/f1/79f1635e3f59f469cfe85150dfec79e055ddf0c8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256007|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1024256007.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256007.html" style="background-color: #494A4F" title="Dark gray">
#  				Dark gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  </ul><div class="new-product">New Arrival</div>
#  </div></article>,
#  <article class="hm-product-item" data-articlecode="0690449051" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449051'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wNTFfZW5fdXM7MDY5MDQ0OTA1MV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0690449051');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0690449051.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/76/92/7692f6468795a359c6dd0bcb0670ea2f9cba4f56.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/00/bb/00bb27c18ef0b3696a52a0a0a38105fdb63335df.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449051|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0690449051.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449051.html" style="background-color: #94989F" title="Gray">
#  				Gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
#  				Black/trashed</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449036.html" style="background-color: #303033" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
#  				Light denim blue/trashed</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0690449043" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449043'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wNDNfZW5fdXM7MDY5MDQ0OTA0M19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0690449043');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0690449043.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/76/e2/76e23bc5c3d3110fd5050a8536728e87b517b01d.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/51/e4/51e42a38e1b2985a3eebe23604ffdb5a934c707e.jpg],origin[dam],category[men_jeans_skinny],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449043|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0690449043.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
#  				Light denim blue/trashed</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
#  				Black/trashed</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449036.html" style="background-color: #303033" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449051.html" style="background-color: #94989F" title="Gray">
#  				Gray</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0690449036" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449036'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wMzZfZW5fdXM7MDY5MDQ0OTAzNl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0690449036');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0690449036.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/58/55/585510d7cd43eb1dd87c268941451a30290e5705.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/25/2a/252a1c07c0470db4d52fd911587e4df7c43170e9.jpg],origin[dam],category[men_jeans_skinny],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449036|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0690449036.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449036.html" style="background-color: #303033" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
#  				Black/trashed</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
#  				Light denim blue/trashed</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449051.html" style="background-color: #94989F" title="Gray">
#  				Gray</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0875105016" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0875105016'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDg3NTEwNV9ncm91cF8wMTZfZW5fdXM7MDg3NTEwNTAxNl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0875105016');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0875105016.html" title="Relaxed Jeans">
#  <img alt="Relaxed JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/a8/b9/a8b924ac35b9e29b573741dbe8459cfb004e70ef.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/42/e6/42e6e5b5479635f5b845d1963ebd69453945cd49.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0875105016|Relaxed Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0875105016.html">Relaxed Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 34.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105016.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105017.html" style="background-color: #54586D" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105018.html" style="background-color: #ADBAD1" title="Pale denim blue">
#  				Pale denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105023.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  </ul><div class="new-product">New Arrival</div>
#  </div></article>,
#  <article class="hm-product-item" data-articlecode="1013317001" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1013317001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAxMzMxN19ncm91cF8wMDFfZW5fdXM7MTAxMzMxNzAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1013317001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1013317001.html" title="Hybrid Regular Tapered Joggers">
#  <img alt="Hybrid Regular Tapered JoggersModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/82/9b/829b20c3ed1399fc081c90ef2bcf76233943e044.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Hybrid Regular Tapered Joggers" data-src="//lp2.hm.com/hmgoepprod?set=source[/da/8f/da8f697b18f361d7226d09bacad42abbb3fba1be.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <div class="promotion-marker" data-tooltip="">
#  				Sustainable Denim</div>
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1013317001|Hybrid Regular Tapered Joggers|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1013317001.html">Hybrid Regular Tapered Joggers</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1013317001.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1013317002.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1013317004.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1013317005.html" style="background-color: #494A4F" title="Dark gray">
#  				Dark gray</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1004199005" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199005'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDVfZW5fdXM7MTAwNDE5OTAwNV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1004199005');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1004199005.html" title="Skinny Cropped Jeans">
#  <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/12/fc/12fc4fd95048b7233754de41a3c2252fa01b7ca1.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/4a/6e/4a6e5dcbafa8c5da31a3e8b1600aceb4c289ef3a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199005|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1004199005.html">Skinny Cropped Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="4">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199005.html" style="background-color: #94989F" title="Light gray">
#  				Light gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199003.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159004" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159004'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDRfZW5fdXM7MDk4NTE1OTAwNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0985159004');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159004.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/e0/cd/e0cd1f7369528e3fd0e1fef3c0a3a1990f06ad87.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/d4/a1/d4a1bdd9d723a874932454e854d6cc5bda5ef688.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159004|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159004.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 24.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
#  				Dark blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0875105023" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0875105023'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDg3NTEwNV9ncm91cF8wMjNfZW5fdXM7MDg3NTEwNTAyM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0875105023');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0875105023.html" title="Relaxed Jeans">
#  <img alt="Relaxed JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/39/46/3946e40e7e45c05219c096431ae2eab6435303fe.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/bd/97/bd97d5e5e4b716a0a2ac10369d4ceb5f12500700.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0875105023|Relaxed Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0875105023.html">Relaxed Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 34.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105023.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105016.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105017.html" style="background-color: #54586D" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105018.html" style="background-color: #ADBAD1" title="Pale denim blue">
#  				Pale denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159005" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159005'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDVfZW5fdXM7MDk4NTE1OTAwNV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0985159005');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159005.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/1f/cc/1fcc801708d85fa6181473072380341c9c1bd219.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/0b/6b/0b6b7a9dc7904561d604839e7cb63f541a37499c.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159005|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159005.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 24.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
#  				Dark blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1008110001" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008110001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODExMF9ncm91cF8wMDFfZW5fdXM7MTAwODExMDAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1008110001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1008110001.html" title="Freefit® Slim Jeans">
#  <img alt="Freefit® Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/3e/8e/3e8e2a02e8951f324e47e8b161285d9fcca8ef83.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Freefit® Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/d4/bf/d4bffdc6ee3a201aefea4020ce97aead158b76c8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008110001|Freefit® Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1008110001.html">Freefit® Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 59.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="3">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008110001.html" style="background-color: #4C5164" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008110002.html" style="background-color: #272628" title="Black/No fade black">
#  				Black/No fade black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008110003.html" style="background-color: #79829D" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul><div class="new-product">New Arrival</div>
#  </div></article>,
#  <article class="hm-product-item" data-articlecode="1004199002" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDJfZW5fdXM7MTAwNDE5OTAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1004199002');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1004199002.html" title="Skinny Cropped Jeans">
#  <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/95/fe/95fe0c8d937eed977512d685f7ab8b2d64464a6d.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/f0/32/f0326127d6dd4265f1fe4a42e590ed7b19241231.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199002|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1004199002.html">Skinny Cropped Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="4">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199003.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199005.html" style="background-color: #94989F" title="Light gray">
#  				Light gray</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159008" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159008'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDhfZW5fdXM7MDk4NTE1OTAwOF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0985159008');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159008.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/86/f7/86f7b1e25d225723055ab84afd366dd7258165ce.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/0c/4e/0c4edaab5321b378dd3481044e6b9de7530195b2.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159008|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159008.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 24.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159008.html" style="background-color: #494A4F" title="Dark gray">
#  				Dark gray</a></li>
# ...
#  <div class="item-buttons">
#  <div class="promotion-marker" data-tooltip="">
#  				Sustainable Denim</div>
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0993887004|Hybrid Regular Denim Joggers|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0993887004.html">Hybrid Regular Denim Joggers</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 44.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="3">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0993887004.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0993887001.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0993887002.html" style="background-color: #8898AC" title="Denim blue">
#  				Denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1013317002" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1013317002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAxMzMxN19ncm91cF8wMDJfZW5fdXM7MTAxMzMxNzAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1013317002');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1013317002.html" title="Hybrid Regular Tapered Joggers">
#  <img alt="Hybrid Regular Tapered JoggersModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/01/0a/010ab4b2d57b35055c5f9ba287cbbeb6b5c7343f.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Hybrid Regular Tapered Joggers" data-src="//lp2.hm.com/hmgoepprod?set=source[/ff/ce/ffce8baee35d1ee3f886fe2cf601f959a651051a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <div class="promotion-marker" data-tooltip="">
#  				Sustainable Denim</div>
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1013317002|Hybrid Regular Tapered Joggers|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1013317002.html">Hybrid Regular Tapered Joggers</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1013317002.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1013317001.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1013317004.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1013317005.html" style="background-color: #494A4F" title="Dark gray">
#  				Dark gray</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159002" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDJfZW5fdXM7MDk4NTE1OTAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0985159002');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159002.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/8d/59/8d592c0d3183668187ca199ea5366e04ed6e35b6.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/83/90/83906d6c2f5c6b94e8cf9f4421412d3270c25f54.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159002|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159002.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 24.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
#  				Dark blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1028865001" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1028865001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyODg2NV9ncm91cF8wMDFfZW5fdXM7MTAyODg2NTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1028865001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1028865001.html" title="Relaxed Jeans with Embroidery Detail">
#  <img alt="Relaxed Jeans with Embroidery DetailModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/2e/6c/2e6cfe32efaaf866815d8736121d7617e78b3676.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans with Embroidery Detail" data-src="//lp2.hm.com/hmgoepprod?set=source[/ad/fb/adfb0576bc1a6af818020f6b824d94e56ce26fb5.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1028865001|Relaxed Jeans with Embroidery Detail|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-collection" style="">
#  		Smiley® x H&amp;M</div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1028865001.html">Relaxed Jeans with Embroidery Detail</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 49.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="1">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1028865001.html" style="background-color: #8898AC" title="Light denim blue/Smiley®">
#  				Light denim blue/Smiley®</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0938875007" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0938875007'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDkzODg3NV9ncm91cF8wMDdfZW5fdXM7MDkzODg3NTAwN19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0938875007');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0938875007.html" title="Slim Tapered Jeans">
#  <img alt="Slim Tapered JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/7d/e4/7de4fe548155af2bcf6ae85a801eb6383a196bc2.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Tapered Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/7e/7e/7e7e2ceb8c0f7564ae999b3ae1e386b99fce62e7.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0938875007|Slim Tapered Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0938875007.html">Slim Tapered Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="3">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0938875007.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0938875010.html" style="background-color: #798DB2" title="Light blue">
#  				Light blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0938875014.html" style="background-color: #33363A" title="Black">
#  				Black</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1008110003" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008110003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODExMF9ncm91cF8wMDNfZW5fdXM7MTAwODExMDAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1008110003');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1008110003.html" title="Freefit® Slim Jeans">
#  <img alt="Freefit® Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/bc/a2/bca288eb687e05f6bdaf839c5f6849e8fc90fef3.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Freefit® Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/c4/2d/c42d20ffb40666f502598225f3d31361476f1a78.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008110003|Freefit® Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1008110003.html">Freefit® Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 59.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="3">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008110003.html" style="background-color: #79829D" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008110001.html" style="background-color: #4C5164" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008110002.html" style="background-color: #272628" title="Black/No fade black">
#  				Black/No fade black</a></li>
#  </ul><div class="new-product">New Arrival</div>
#  </div></article>,
#  <article class="hm-product-item" data-articlecode="0985197001" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985197001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE5N19ncm91cF8wMDFfZW5fdXM7MDk4NTE5NzAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','0985197001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985197001.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/b6/26/b626e8a76cc287928788b5edc8d1fa2679440a88.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/6a/6a/6a6adf7dede242a98b194fee7cc8f60e4737ae0a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985197001|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985197001.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="3">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197003.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197006.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>]

# %%
products_list[0]
# Out:
# <article class="hm-product-item" data-articlecode="1024256001" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDFfZW5fdXM7MTAyNDI1NjAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTsyMTs','1024256001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256001.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/77/b5/77b566ce3845791ecb47a6252b6c1e16fd93ea68.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/00/0b/000b5d6009a7bd05a76a9ec22f8bd784f4b2271a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/00/0b/000b5d6009a7bd05a76a9ec22f8bd784f4b2271a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256001|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256001.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256005.html" style="background-color: #2F323B" title="Dark blue">
# 				Dark blue</a></li>
# </ul></div></article>

# %%
len(products_list)
# Out:
# 36

# %% [markdown]
# #### Filtrando id

# %%
products_list[0].get('data-articlecode')
# Out:
# '1024256001'

# %%
products_id = [p.get('data-articlecode') for p in products_list]

# %%
products_id
# Out:
# ['1024256001',
#  '1024256003',
#  '0690449056',
#  '0985159001',
#  '0690449022',
#  '1024256004',
#  '1024256007',
#  '0690449051',
#  '0690449043',
#  '0690449036',
#  '0875105016',
#  '1013317001',
#  '1004199005',
#  '0985159004',
#  '0875105023',
#  '0985159005',
#  '1008110001',
#  '1004199002',
#  '0985159008',
#  '1024711001',
#  '0875105018',
#  '1013317008',
#  '0974202003',
#  '1013317006',
#  '0875105024',
#  '0938875014',
#  '1008549002',
#  '1024256006',
#  '1013317010',
#  '0993887004',
#  '1013317002',
#  '0985159002',
#  '1028865001',
#  '0938875007',
#  '1008110003',
#  '0985197001']

# %% [markdown]
# #### Filtrando category/type

# %%
products_category = [p.get('data-category') for p in products_list]

# %%
products_category
# Out:
# ['men_jeans_slim',
#  'men_jeans_slim',
#  'men_jeans_ripped',
#  'men_jeans_skinny',
#  'men_jeans_ripped',
#  'men_jeans_slim',
#  'men_jeans_slim',
#  'men_jeans_ripped',
#  'men_jeans_ripped',
#  'men_jeans_ripped',
#  'men_jeans_relaxed',
#  'men_jeans_regular',
#  'men_jeans_skinny',
#  'men_jeans_skinny',
#  'men_jeans_relaxed',
#  'men_jeans_skinny',
#  'men_jeans_slim',
#  'men_jeans_skinny',
#  'men_jeans_skinny',
#  'men_jeans_slim',
#  'men_jeans_relaxed',
#  'men_jeans_regular',
#  'men_jeans_loose',
#  'men_jeans_regular',
#  'men_jeans_relaxed',
#  'men_jeans_slim',
#  'men_jeans_regular',
#  'men_jeans_slim',
#  'men_jeans_regular',
#  'men_jeans_regular',
#  'men_jeans_regular',
#  'men_jeans_skinny',
#  'men_jeans_relaxed',
#  'men_jeans_slim',
#  'men_jeans_slim',
#  'men_jeans_slim']

# %% [markdown]
# #### Filtrando nome do produto

# %%
products.find_all('a', 'link')
# Out:
# [<a class="link" href="/en_us/productpage.1024256001.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.1024256003.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.0690449056.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0985159001.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0690449022.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.1024256004.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.1024256007.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.0690449051.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0690449043.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0690449036.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0875105016.html">Relaxed Jeans</a>,
#  <a class="link" href="/en_us/productpage.1013317001.html">Hybrid Regular Tapered Joggers</a>,
#  <a class="link" href="/en_us/productpage.1004199005.html">Skinny Cropped Jeans</a>,
#  <a class="link" href="/en_us/productpage.0985159004.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0875105023.html">Relaxed Jeans</a>,
#  <a class="link" href="/en_us/productpage.0985159005.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.1008110001.html">Freefit® Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.1004199002.html">Skinny Cropped Jeans</a>,
#  <a class="link" href="/en_us/productpage.0985159008.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.1024711001.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.0875105018.html">Relaxed Jeans</a>,
#  <a class="link" href="/en_us/productpage.1013317008.html">Hybrid Regular Tapered Joggers</a>,
#  <a class="link" href="/en_us/productpage.0974202003.html">Regular Denim Joggers</a>,
#  <a class="link" href="/en_us/productpage.1013317006.html">Hybrid Regular Tapered Joggers</a>,
#  <a class="link" href="/en_us/productpage.0875105024.html">Relaxed Jeans</a>,
#  <a class="link" href="/en_us/productpage.0938875014.html">Slim Tapered Jeans</a>,
#  <a class="link" href="/en_us/productpage.1008549002.html">Regular Jeans</a>,
#  <a class="link" href="/en_us/productpage.1024256006.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.1013317010.html">Hybrid Regular Tapered Joggers</a>,
#  <a class="link" href="/en_us/productpage.0993887004.html">Hybrid Regular Denim Joggers</a>,
#  <a class="link" href="/en_us/productpage.1013317002.html">Hybrid Regular Tapered Joggers</a>,
#  <a class="link" href="/en_us/productpage.0985159002.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.1028865001.html">Relaxed Jeans with Embroidery Detail</a>,
#  <a class="link" href="/en_us/productpage.0938875007.html">Slim Tapered Jeans</a>,
#  <a class="link" href="/en_us/productpage.1008110003.html">Freefit® Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.0985197001.html">Slim Jeans</a>]

# %%
product_name = products.find_all('a', 'link')

# %%
product_name = [p.get_text() for p in product_name]

# %%
product_name
# Out:
# ['Slim Jeans',
#  'Slim Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans',
#  'Slim Jeans',
#  'Slim Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans',
#  'Relaxed Jeans',
#  'Hybrid Regular Tapered Joggers',
#  'Skinny Cropped Jeans',
#  'Skinny Jeans',
#  'Relaxed Jeans',
#  'Skinny Jeans',
#  'Freefit® Slim Jeans',
#  'Skinny Cropped Jeans',
#  'Skinny Jeans',
#  'Slim Jeans',
#  'Relaxed Jeans',
#  'Hybrid Regular Tapered Joggers',
#  'Regular Denim Joggers',
#  'Hybrid Regular Tapered Joggers',
#  'Relaxed Jeans',
#  'Slim Tapered Jeans',
#  'Regular Jeans',
#  'Slim Jeans',
#  'Hybrid Regular Tapered Joggers',
#  'Hybrid Regular Denim Joggers',
#  'Hybrid Regular Tapered Joggers',
#  'Skinny Jeans',
#  'Relaxed Jeans with Embroidery Detail',
#  'Slim Tapered Jeans',
#  'Freefit® Slim Jeans',
#  'Slim Jeans']

# %% [markdown]
# #### Filtrando preço

# %%
products.find_all('span', 'price regular')
# Out:
# [<span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 24.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 34.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 24.99</span>,
#  <span class="price regular">$ 34.99</span>,
#  <span class="price regular">$ 24.99</span>,
#  <span class="price regular">$ 59.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 24.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 34.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 34.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 24.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 44.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 24.99</span>,
#  <span class="price regular">$ 49.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 59.99</span>,
#  <span class="price regular">$ 19.99</span>]

# %%
product_price = products.find_all('span', 'price regular')

# %%
product_price = [p.get_text() for p in product_price]

# %%
product_price
# Out:
# ['$ 19.99',
#  '$ 19.99',
#  '$ 39.99',
#  '$ 24.99',
#  '$ 39.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 39.99',
#  '$ 39.99',
#  '$ 39.99',
#  '$ 34.99',
#  '$ 39.99',
#  '$ 29.99',
#  '$ 24.99',
#  '$ 34.99',
#  '$ 24.99',
#  '$ 59.99',
#  '$ 29.99',
#  '$ 24.99',
#  '$ 29.99',
#  '$ 34.99',
#  '$ 39.99',
#  '$ 29.99',
#  '$ 39.99',
#  '$ 34.99',
#  '$ 39.99',
#  '$ 24.99',
#  '$ 19.99',
#  '$ 39.99',
#  '$ 44.99',
#  '$ 39.99',
#  '$ 24.99',
#  '$ 49.99',
#  '$ 39.99',
#  '$ 59.99',
#  '$ 19.99']

# %% [markdown]
# #### Dataframe com os dados coletados até o momento

# %%
pd.DataFrame([products_id, product_name, products_category, product_price])
# Out:
#                0               1                 2                 3   \
# 0      1024256001      1024256003        0690449056        0985159001
# 1      Slim Jeans      Slim Jeans      Skinny Jeans      Skinny Jeans
# 2  men_jeans_slim  men_jeans_slim  men_jeans_ripped  men_jeans_skinny
# 3         $ 19.99         $ 19.99           $ 39.99           $ 24.99
#
#                  4               5               6                 7   \
# 0        0690449022      1024256004      1024256007        0690449051
# 1      Skinny Jeans      Slim Jeans      Slim Jeans      Skinny Jeans
# 2  men_jeans_ripped  men_jeans_slim  men_jeans_slim  men_jeans_ripped
# 3           $ 39.99         $ 19.99         $ 19.99           $ 39.99
#
#                  8                 9   ...                 26              27  \
# 0        0690449043        0690449036  ...         1008549002      1024256006
# 1      Skinny Jeans      Skinny Jeans  ...      Regular Jeans      Slim Jeans
# 2  men_jeans_ripped  men_jeans_ripped  ...  men_jeans_regular  men_jeans_slim
# 3           $ 39.99           $ 39.99  ...            $ 24.99         $ 19.99
#
#                                28                            29  \
# 0                      1013317010                    0993887004
# 1  Hybrid Regular Tapered Joggers  Hybrid Regular Denim Joggers
# 2               men_jeans_regular             men_jeans_regular
# 3                         $ 39.99                       $ 44.99
#
#                                30                31  \
# 0                      1013317002        0985159002
# 1  Hybrid Regular Tapered Joggers      Skinny Jeans
# 2               men_jeans_regular  men_jeans_skinny
# 3                         $ 39.99           $ 24.99
#
#                                      32                  33  \
# 0                            1028865001          0938875007
# 1  Relaxed Jeans with Embroidery Detail  Slim Tapered Jeans
# 2                     men_jeans_relaxed      men_jeans_slim
# 3                               $ 49.99             $ 39.99
#
#                     34              35
# 0           1008110003      0985197001
# 1  Freefit® Slim Jeans      Slim Jeans
# 2       men_jeans_slim  men_jeans_slim
# 3              $ 59.99         $ 19.99
#
# [4 rows x 36 columns]

# %%
pd.DataFrame([products_id, product_name, products_category, product_price]).T
# Out:
#              0                                     1                  2  \
# 0   1024256001                            Slim Jeans     men_jeans_slim
# 1   1024256003                            Slim Jeans     men_jeans_slim
# 2   0690449056                          Skinny Jeans   men_jeans_ripped
# 3   0985159001                          Skinny Jeans   men_jeans_skinny
# 4   0690449022                          Skinny Jeans   men_jeans_ripped
# 5   1024256004                            Slim Jeans     men_jeans_slim
# 6   1024256007                            Slim Jeans     men_jeans_slim
# 7   0690449051                          Skinny Jeans   men_jeans_ripped
# 8   0690449043                          Skinny Jeans   men_jeans_ripped
# 9   0690449036                          Skinny Jeans   men_jeans_ripped
# 10  0875105016                         Relaxed Jeans  men_jeans_relaxed
# 11  1013317001        Hybrid Regular Tapered Joggers  men_jeans_regular
# 12  1004199005                  Skinny Cropped Jeans   men_jeans_skinny
# 13  0985159004                          Skinny Jeans   men_jeans_skinny
# 14  0875105023                         Relaxed Jeans  men_jeans_relaxed
# 15  0985159005                          Skinny Jeans   men_jeans_skinny
# 16  1008110001                   Freefit® Slim Jeans     men_jeans_slim
# 17  1004199002                  Skinny Cropped Jeans   men_jeans_skinny
# 18  0985159008                          Skinny Jeans   men_jeans_skinny
# 19  1024711001                            Slim Jeans     men_jeans_slim
# 20  0875105018                         Relaxed Jeans  men_jeans_relaxed
# 21  1013317008        Hybrid Regular Tapered Joggers  men_jeans_regular
# 22  0974202003                 Regular Denim Joggers    men_jeans_loose
# 23  1013317006        Hybrid Regular Tapered Joggers  men_jeans_regular
# 24  0875105024                         Relaxed Jeans  men_jeans_relaxed
# 25  0938875014                    Slim Tapered Jeans     men_jeans_slim
# 26  1008549002                         Regular Jeans  men_jeans_regular
# 27  1024256006                            Slim Jeans     men_jeans_slim
# 28  1013317010        Hybrid Regular Tapered Joggers  men_jeans_regular
# 29  0993887004          Hybrid Regular Denim Joggers  men_jeans_regular
# 30  1013317002        Hybrid Regular Tapered Joggers  men_jeans_regular
# 31  0985159002                          Skinny Jeans   men_jeans_skinny
# 32  1028865001  Relaxed Jeans with Embroidery Detail  men_jeans_relaxed
# 33  0938875007                    Slim Tapered Jeans     men_jeans_slim
# 34  1008110003                   Freefit® Slim Jeans     men_jeans_slim
# 35  0985197001                            Slim Jeans     men_jeans_slim
#
#           3
# 0   $ 19.99
# 1   $ 19.99
# 2   $ 39.99
# 3   $ 24.99
# 4   $ 39.99
# 5   $ 19.99
# 6   $ 19.99
# 7   $ 39.99
# 8   $ 39.99
# 9   $ 39.99
# 10  $ 34.99
# 11  $ 39.99
# 12  $ 29.99
# 13  $ 24.99
# 14  $ 34.99
# 15  $ 24.99
# 16  $ 59.99
# 17  $ 29.99
# 18  $ 24.99
# 19  $ 29.99
# 20  $ 34.99
# 21  $ 39.99
# 22  $ 29.99
# 23  $ 39.99
# 24  $ 34.99
# 25  $ 39.99
# 26  $ 24.99
# 27  $ 19.99
# 28  $ 39.99
# 29  $ 44.99
# 30  $ 39.99
# 31  $ 24.99
# 32  $ 49.99
# 33  $ 39.99
# 34  $ 59.99
# 35  $ 19.99

# %%
data = pd.DataFrame([products_id, product_name, products_category, product_price]).T
data.columns = ['id', 'product_name', 'product_type', 'price']

# %%
data
# Out:
#             id                          product_name       product_type  \
# 0   1024256001                            Slim Jeans     men_jeans_slim
# 1   1024256003                            Slim Jeans     men_jeans_slim
# 2   0690449056                          Skinny Jeans   men_jeans_ripped
# 3   0985159001                          Skinny Jeans   men_jeans_skinny
# 4   0690449022                          Skinny Jeans   men_jeans_ripped
# 5   1024256004                            Slim Jeans     men_jeans_slim
# 6   1024256007                            Slim Jeans     men_jeans_slim
# 7   0690449051                          Skinny Jeans   men_jeans_ripped
# 8   0690449043                          Skinny Jeans   men_jeans_ripped
# 9   0690449036                          Skinny Jeans   men_jeans_ripped
# 10  0875105016                         Relaxed Jeans  men_jeans_relaxed
# 11  1013317001        Hybrid Regular Tapered Joggers  men_jeans_regular
# 12  1004199005                  Skinny Cropped Jeans   men_jeans_skinny
# 13  0985159004                          Skinny Jeans   men_jeans_skinny
# 14  0875105023                         Relaxed Jeans  men_jeans_relaxed
# 15  0985159005                          Skinny Jeans   men_jeans_skinny
# 16  1008110001                   Freefit® Slim Jeans     men_jeans_slim
# 17  1004199002                  Skinny Cropped Jeans   men_jeans_skinny
# 18  0985159008                          Skinny Jeans   men_jeans_skinny
# 19  1024711001                            Slim Jeans     men_jeans_slim
# 20  0875105018                         Relaxed Jeans  men_jeans_relaxed
# 21  1013317008        Hybrid Regular Tapered Joggers  men_jeans_regular
# 22  0974202003                 Regular Denim Joggers    men_jeans_loose
# 23  1013317006        Hybrid Regular Tapered Joggers  men_jeans_regular
# 24  0875105024                         Relaxed Jeans  men_jeans_relaxed
# 25  0938875014                    Slim Tapered Jeans     men_jeans_slim
# 26  1008549002                         Regular Jeans  men_jeans_regular
# 27  1024256006                            Slim Jeans     men_jeans_slim
# 28  1013317010        Hybrid Regular Tapered Joggers  men_jeans_regular
# 29  0993887004          Hybrid Regular Denim Joggers  men_jeans_regular
# 30  1013317002        Hybrid Regular Tapered Joggers  men_jeans_regular
# 31  0985159002                          Skinny Jeans   men_jeans_skinny
# 32  1028865001  Relaxed Jeans with Embroidery Detail  men_jeans_relaxed
# 33  0938875007                    Slim Tapered Jeans     men_jeans_slim
# 34  1008110003                   Freefit® Slim Jeans     men_jeans_slim
# 35  0985197001                            Slim Jeans     men_jeans_slim
#
#       price
# 0   $ 19.99
# 1   $ 19.99
# 2   $ 39.99
# 3   $ 24.99
# 4   $ 39.99
# 5   $ 19.99
# 6   $ 19.99
# 7   $ 39.99
# 8   $ 39.99
# 9   $ 39.99
# 10  $ 34.99
# 11  $ 39.99
# 12  $ 29.99
# 13  $ 24.99
# 14  $ 34.99
# 15  $ 24.99
# 16  $ 59.99
# 17  $ 29.99
# 18  $ 24.99
# 19  $ 29.99
# 20  $ 34.99
# 21  $ 39.99
# 22  $ 29.99
# 23  $ 39.99
# 24  $ 34.99
# 25  $ 39.99
# 26  $ 24.99
# 27  $ 19.99
# 28  $ 39.99
# 29  $ 44.99
# 30  $ 39.99
# 31  $ 24.99
# 32  $ 49.99
# 33  $ 39.99
# 34  $ 59.99
# 35  $ 19.99

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 1, 24, 14, 43, 5, 573563)

# %%
datetime.now().strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-01-24 14:43:05'

# %%
data['datetime'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
data
# Out:
#             id                          product_name       product_type  \
# 0   1024256001                            Slim Jeans     men_jeans_slim
# 1   1024256003                            Slim Jeans     men_jeans_slim
# 2   0690449056                          Skinny Jeans   men_jeans_ripped
# 3   0985159001                          Skinny Jeans   men_jeans_skinny
# 4   0690449022                          Skinny Jeans   men_jeans_ripped
# 5   1024256004                            Slim Jeans     men_jeans_slim
# 6   1024256007                            Slim Jeans     men_jeans_slim
# 7   0690449051                          Skinny Jeans   men_jeans_ripped
# 8   0690449043                          Skinny Jeans   men_jeans_ripped
# 9   0690449036                          Skinny Jeans   men_jeans_ripped
# 10  0875105016                         Relaxed Jeans  men_jeans_relaxed
# 11  1013317001        Hybrid Regular Tapered Joggers  men_jeans_regular
# 12  1004199005                  Skinny Cropped Jeans   men_jeans_skinny
# 13  0985159004                          Skinny Jeans   men_jeans_skinny
# 14  0875105023                         Relaxed Jeans  men_jeans_relaxed
# 15  0985159005                          Skinny Jeans   men_jeans_skinny
# 16  1008110001                   Freefit® Slim Jeans     men_jeans_slim
# 17  1004199002                  Skinny Cropped Jeans   men_jeans_skinny
# 18  0985159008                          Skinny Jeans   men_jeans_skinny
# 19  1024711001                            Slim Jeans     men_jeans_slim
# 20  0875105018                         Relaxed Jeans  men_jeans_relaxed
# 21  1013317008        Hybrid Regular Tapered Joggers  men_jeans_regular
# 22  0974202003                 Regular Denim Joggers    men_jeans_loose
# 23  1013317006        Hybrid Regular Tapered Joggers  men_jeans_regular
# 24  0875105024                         Relaxed Jeans  men_jeans_relaxed
# 25  0938875014                    Slim Tapered Jeans     men_jeans_slim
# 26  1008549002                         Regular Jeans  men_jeans_regular
# 27  1024256006                            Slim Jeans     men_jeans_slim
# 28  1013317010        Hybrid Regular Tapered Joggers  men_jeans_regular
# 29  0993887004          Hybrid Regular Denim Joggers  men_jeans_regular
# 30  1013317002        Hybrid Regular Tapered Joggers  men_jeans_regular
# 31  0985159002                          Skinny Jeans   men_jeans_skinny
# 32  1028865001  Relaxed Jeans with Embroidery Detail  men_jeans_relaxed
# 33  0938875007                    Slim Tapered Jeans     men_jeans_slim
# 34  1008110003                   Freefit® Slim Jeans     men_jeans_slim
# 35  0985197001                            Slim Jeans     men_jeans_slim
#
#       price             datetime
# 0   $ 19.99  2022-01-24 14:43:05
# 1   $ 19.99  2022-01-24 14:43:05
# 2   $ 39.99  2022-01-24 14:43:05
# 3   $ 24.99  2022-01-24 14:43:05
# 4   $ 39.99  2022-01-24 14:43:05
# 5   $ 19.99  2022-01-24 14:43:05
# 6   $ 19.99  2022-01-24 14:43:05
# 7   $ 39.99  2022-01-24 14:43:05
# 8   $ 39.99  2022-01-24 14:43:05
# 9   $ 39.99  2022-01-24 14:43:05
# 10  $ 34.99  2022-01-24 14:43:05
# 11  $ 39.99  2022-01-24 14:43:05
# 12  $ 29.99  2022-01-24 14:43:05
# 13  $ 24.99  2022-01-24 14:43:05
# 14  $ 34.99  2022-01-24 14:43:05
# 15  $ 24.99  2022-01-24 14:43:05
# 16  $ 59.99  2022-01-24 14:43:05
# 17  $ 29.99  2022-01-24 14:43:05
# 18  $ 24.99  2022-01-24 14:43:05
# 19  $ 29.99  2022-01-24 14:43:05
# 20  $ 34.99  2022-01-24 14:43:05
# 21  $ 39.99  2022-01-24 14:43:05
# 22  $ 29.99  2022-01-24 14:43:05
# 23  $ 39.99  2022-01-24 14:43:05
# 24  $ 34.99  2022-01-24 14:43:05
# 25  $ 39.99  2022-01-24 14:43:05
# 26  $ 24.99  2022-01-24 14:43:05
# 27  $ 19.99  2022-01-24 14:43:05
# 28  $ 39.99  2022-01-24 14:43:05
# 29  $ 44.99  2022-01-24 14:43:05
# 30  $ 39.99  2022-01-24 14:43:05
# 31  $ 24.99  2022-01-24 14:43:05
# 32  $ 49.99  2022-01-24 14:43:05
# 33  $ 39.99  2022-01-24 14:43:05
# 34  $ 59.99  2022-01-24 14:43:05
# 35  $ 19.99  2022-01-24 14:43:05

# %% [markdown]
# ## Pagination/Paginação

# %% [markdown]
# Precisamos identificar o número total de páginas.

# %%
soup.find_all('h2', 'load-more-heading')[0]
# Out:
# <h2 class="load-more-heading" data-items-shown="36" data-total="64">SHOWING 36 of 64 Items</h2>

# %%
total_itens = soup.find_all('h2', 'load-more-heading')[0].get('data-total')
total_itens
# Out:
# '64'

# %% [markdown]
# Note que o valor acima é da classe do tipo string. Por isso, vamos transformá-lo em inteiro, conforme o comando abaixo:

# %%
int(total_itens)
# Out:
# 64

# %% [markdown]
# Cada vitrine da H&M para calças jeans masculina possui o valor de 36 itens. Então, vamos coletar os dados de 36 em 36 itens. Por isso, para saber o número de paginação, fazemos:

# %%
int(total_itens)/36
# Out:
# 1.7777777777777777

# %%
np.round(int(total_itens)/36)
# Out:
# 2.0

# %%
pagination_number = np.round(int(total_itens)/36)
pagination_number
# Out:
# 2.0

# %% [markdown]
# Então, vamos precisar de duas paginações. Agora, vamos identificar o 'page-size' da nossa url para saber o tamanho da vitrine que temos que colocar na nossa url para trazer todos os itens.

# %%
url02 = url + '?page-size=' + str(int(pagination_number*36))
url02
# Out:
# 'https://www2.hm.com/en_us/men/products/jeans.html?page-size=72'

# %% [markdown]
# Embora o número total de itens seja 57, para trazer todos os itens devemos fazer uma paginação tal qual o valor de page-size seja o acima.

# %% [markdown]
# #### Restante da vitrine

# %%
url02 = "https://www2.hm.com/en_us/men/products/jeans.html?sort=stock&image-size=small&image=model&offset=0&page-size=72"

# conteúdo de headers é padrão
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
page = requests.get(url02, headers=headers)

soup = BeautifulSoup(page.text, 'html.parser')

products_list = products.find_all('article', 'hm-product-item')
products_id = [p.get('data-articlecode') for p in products_list]
products_category = [p.get('data-category') for p in products_list]

product_name = products.find_all('a', 'link')
product_name = [p.get_text() for p in product_name]

product_price = products.find_all('span', 'price regular')
product_price = [p.get_text() for p in product_price]

data = pd.DataFrame([products_id, product_name, products_category, product_price]).T
data.columns = ['id', 'product_name', 'product_type', 'price']

datetime.now()
datetime.now().strftime('%Y-%m-%d %H:%M:%S')
data['datetime'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
data
# Out:
#             id                          product_name       product_type  \
# 0   1024256001                            Slim Jeans     men_jeans_slim
# 1   1024256003                            Slim Jeans     men_jeans_slim
# 2   0690449056                          Skinny Jeans   men_jeans_ripped
# 3   0985159001                          Skinny Jeans   men_jeans_skinny
# 4   0690449022                          Skinny Jeans   men_jeans_ripped
# 5   1024256004                            Slim Jeans     men_jeans_slim
# 6   1024256007                            Slim Jeans     men_jeans_slim
# 7   0690449051                          Skinny Jeans   men_jeans_ripped
# 8   0690449043                          Skinny Jeans   men_jeans_ripped
# 9   0690449036                          Skinny Jeans   men_jeans_ripped
# 10  0875105016                         Relaxed Jeans  men_jeans_relaxed
# 11  1013317001        Hybrid Regular Tapered Joggers  men_jeans_regular
# 12  1004199005                  Skinny Cropped Jeans   men_jeans_skinny
# 13  0985159004                          Skinny Jeans   men_jeans_skinny
# 14  0875105023                         Relaxed Jeans  men_jeans_relaxed
# 15  0985159005                          Skinny Jeans   men_jeans_skinny
# 16  1008110001                   Freefit® Slim Jeans     men_jeans_slim
# 17  1004199002                  Skinny Cropped Jeans   men_jeans_skinny
# 18  0985159008                          Skinny Jeans   men_jeans_skinny
# 19  1024711001                            Slim Jeans     men_jeans_slim
# 20  0875105018                         Relaxed Jeans  men_jeans_relaxed
# 21  1013317008        Hybrid Regular Tapered Joggers  men_jeans_regular
# 22  0974202003                 Regular Denim Joggers    men_jeans_loose
# 23  1013317006        Hybrid Regular Tapered Joggers  men_jeans_regular
# 24  0875105024                         Relaxed Jeans  men_jeans_relaxed
# 25  0938875014                    Slim Tapered Jeans     men_jeans_slim
# 26  1008549002                         Regular Jeans  men_jeans_regular
# 27  1024256006                            Slim Jeans     men_jeans_slim
# 28  1013317010        Hybrid Regular Tapered Joggers  men_jeans_regular
# 29  0993887004          Hybrid Regular Denim Joggers  men_jeans_regular
# 30  1013317002        Hybrid Regular Tapered Joggers  men_jeans_regular
# 31  0985159002                          Skinny Jeans   men_jeans_skinny
# 32  1028865001  Relaxed Jeans with Embroidery Detail  men_jeans_relaxed
# 33  0938875007                    Slim Tapered Jeans     men_jeans_slim
# 34  1008110003                   Freefit® Slim Jeans     men_jeans_slim
# 35  0985197001                            Slim Jeans     men_jeans_slim
#
#       price             datetime
# 0   $ 19.99  2022-01-24 14:43:08
# 1   $ 19.99  2022-01-24 14:43:08
# 2   $ 39.99  2022-01-24 14:43:08
# 3   $ 24.99  2022-01-24 14:43:08
# 4   $ 39.99  2022-01-24 14:43:08
# 5   $ 19.99  2022-01-24 14:43:08
# 6   $ 19.99  2022-01-24 14:43:08
# 7   $ 39.99  2022-01-24 14:43:08
# 8   $ 39.99  2022-01-24 14:43:08
# 9   $ 39.99  2022-01-24 14:43:08
# 10  $ 34.99  2022-01-24 14:43:08
# 11  $ 39.99  2022-01-24 14:43:08
# 12  $ 29.99  2022-01-24 14:43:08
# 13  $ 24.99  2022-01-24 14:43:08
# 14  $ 34.99  2022-01-24 14:43:08
# 15  $ 24.99  2022-01-24 14:43:08
# 16  $ 59.99  2022-01-24 14:43:08
# 17  $ 29.99  2022-01-24 14:43:08
# 18  $ 24.99  2022-01-24 14:43:08
# 19  $ 29.99  2022-01-24 14:43:08
# 20  $ 34.99  2022-01-24 14:43:08
# 21  $ 39.99  2022-01-24 14:43:08
# 22  $ 29.99  2022-01-24 14:43:08
# 23  $ 39.99  2022-01-24 14:43:08
# 24  $ 34.99  2022-01-24 14:43:08
# 25  $ 39.99  2022-01-24 14:43:08
# 26  $ 24.99  2022-01-24 14:43:08
# 27  $ 19.99  2022-01-24 14:43:08
# 28  $ 39.99  2022-01-24 14:43:08
# 29  $ 44.99  2022-01-24 14:43:08
# 30  $ 39.99  2022-01-24 14:43:08
# 31  $ 24.99  2022-01-24 14:43:08
# 32  $ 49.99  2022-01-24 14:43:08
# 33  $ 39.99  2022-01-24 14:43:08
# 34  $ 59.99  2022-01-24 14:43:08
# 35  $ 19.99  2022-01-24 14:43:08

# %% [markdown]
# #### Filtrando por cor

# %% [markdown]
# A cor só pode ser coletada na página do produto e não na vitrine.

# %% [markdown]
# Inicialmente, vamos fazer só para um produto.

# %%
#API request
url = "https://www2.hm.com/en_us/productpage.1024256001.html"

# conteúdo de headers é padrão
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
page = requests.get(url, headers=headers)

# %%
#Beautiful Soup object
soup = BeautifulSoup(page.text, 'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.find_all('li', 'list-item')
# Out:
# [<li class="list-item">
#  <a class="link" data-remodal-trigger="signin-account" href="/en_us/account">My Account</a>
#  </li>,
#  <li class="list-item">
#  <a class="link" href="/en_us/member/info.html">Loyalty Program Info</a>
#  </li>,
#  <li class="list-item">
#  <a class="link" data-remodal-trigger="join" href="#">Not a Member yet? Join here!</a>
#  </li>,
#  <li class="list-item">
#  <a class="link" href="/en_us/account">My Account</a>
#  </li>,
#  <li class="list-item">
#  <a class="link" href="/en_us/member/info.html">Loyalty Program Info</a>
#  </li>,
#  <li class="list-item">
#  <a class="link" href="/en_us/logout" onclick="trackLogout()">Sign out</a>
#  </li>,
#  <li class="list-item">
#  <a aria-checked="true" class="filter-option miniature active" data-articlecode="1024256001" data-color="Black" data-sizes="" href="/en_us/productpage.1024256001.html" id="filter-colour-1024256001" role="radio" title="Black">
#  <noscript data-alt="Black" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F77%2Fb5%2F77b566ce3845791ecb47a6252b6c1e16fd93ea68.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Black" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F77%2Fb5%2F77b566ce3845791ecb47a6252b6c1e16fd93ea68.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>
#  </li>,
#  <li class="list-item hidden">
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="1024256002" data-color="Light denim blue" data-sizes="" href="/en_us/productpage.1024256002.html" id="filter-colour-1024256002" role="radio" title="Light denim blue">
#  <noscript data-alt="Light denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fda%2Fba%2Fdabaf3f73477f46b068e2e02033aa0222206ef7f.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Light denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fda%2Fba%2Fdabaf3f73477f46b068e2e02033aa0222206ef7f.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>
#  </li>,
#  <li class="list-item hidden">
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="1024256003" data-color="Light denim blue" data-sizes="" href="/en_us/productpage.1024256003.html" id="filter-colour-1024256003" role="radio" title="Light denim blue">
#  <noscript data-alt="Light denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fe3%2Fe8%2Fe3e81b8bc860bd9ba65e2940d0a7c9635d42cc66.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Light denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fe3%2Fe8%2Fe3e81b8bc860bd9ba65e2940d0a7c9635d42cc66.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>
#  </li>,
#  <li class="list-item hidden">
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="1024256004" data-color="Denim blue" data-sizes="" href="/en_us/productpage.1024256004.html" id="filter-colour-1024256004" role="radio" title="Denim blue">
#  <noscript data-alt="Denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F79%2F34%2F7934a8d7525532547dfef00416aba449e58493d1.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F79%2F34%2F7934a8d7525532547dfef00416aba449e58493d1.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>
#  </li>,
#  <li class="list-item hidden">
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="1024256005" data-color="Dark blue" data-sizes="" href="/en_us/productpage.1024256005.html" id="filter-colour-1024256005" role="radio" title="Dark blue">
#  <noscript data-alt="Dark blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F5a%2F97%2F5a9787e31a37242c09b67d2f224bbd8b1c999c35.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Dark blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F5a%2F97%2F5a9787e31a37242c09b67d2f224bbd8b1c999c35.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>
#  </li>,
#  <li class="list-item hidden">
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="1024256006" data-color="Dark denim blue" data-sizes="" href="/en_us/productpage.1024256006.html" id="filter-colour-1024256006" role="radio" title="Dark denim blue">
#  <noscript data-alt="Dark denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fa9%2Fb8%2Fa9b8a08f975093716aaaea2f3c75a944af2c09d5.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Dark denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fa9%2Fb8%2Fa9b8a08f975093716aaaea2f3c75a944af2c09d5.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>
#  </li>,
#  <li class="list-item hidden">
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="1024256007" data-color="Dark gray" data-sizes="" href="/en_us/productpage.1024256007.html" id="filter-colour-1024256007" role="radio" title="Dark gray">
#  <noscript data-alt="Dark gray" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fcd%2F7b%2Fcd7b894fba8c32078439f442e205ef9d719e8fb0.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Dark gray" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fcd%2F7b%2Fcd7b894fba8c32078439f442e205ef9d719e8fb0.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>
#  </li>,
#  <li class="list-item">
#  <a href="/en_us/men/products/jeans/slim-fit.html?colorWithNames=gray_808080">GRAY SLIM JEANS FOR MEN</a>
#  </li>]

# %%
soup.find_all('a', 'filter-option miniature')
# Out:
# [<a aria-checked="false" class="filter-option miniature" data-articlecode="1024256002" data-color="Light denim blue" data-sizes="" href="/en_us/productpage.1024256002.html" id="filter-colour-1024256002" role="radio" title="Light denim blue">
#  <noscript data-alt="Light denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fda%2Fba%2Fdabaf3f73477f46b068e2e02033aa0222206ef7f.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Light denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fda%2Fba%2Fdabaf3f73477f46b068e2e02033aa0222206ef7f.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="1024256003" data-color="Light denim blue" data-sizes="" href="/en_us/productpage.1024256003.html" id="filter-colour-1024256003" role="radio" title="Light denim blue">
#  <noscript data-alt="Light denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fe3%2Fe8%2Fe3e81b8bc860bd9ba65e2940d0a7c9635d42cc66.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Light denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fe3%2Fe8%2Fe3e81b8bc860bd9ba65e2940d0a7c9635d42cc66.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="1024256004" data-color="Denim blue" data-sizes="" href="/en_us/productpage.1024256004.html" id="filter-colour-1024256004" role="radio" title="Denim blue">
#  <noscript data-alt="Denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F79%2F34%2F7934a8d7525532547dfef00416aba449e58493d1.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F79%2F34%2F7934a8d7525532547dfef00416aba449e58493d1.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="1024256005" data-color="Dark blue" data-sizes="" href="/en_us/productpage.1024256005.html" id="filter-colour-1024256005" role="radio" title="Dark blue">
#  <noscript data-alt="Dark blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F5a%2F97%2F5a9787e31a37242c09b67d2f224bbd8b1c999c35.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Dark blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F5a%2F97%2F5a9787e31a37242c09b67d2f224bbd8b1c999c35.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="1024256006" data-color="Dark denim blue" data-sizes="" href="/en_us/productpage.1024256006.html" id="filter-colour-1024256006" role="radio" title="Dark denim blue">
#  <noscript data-alt="Dark denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fa9%2Fb8%2Fa9b8a08f975093716aaaea2f3c75a944af2c09d5.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Dark denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fa9%2Fb8%2Fa9b8a08f975093716aaaea2f3c75a944af2c09d5.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="1024256007" data-color="Dark gray" data-sizes="" href="/en_us/productpage.1024256007.html" id="filter-colour-1024256007" role="radio" title="Dark gray">
#  <noscript data-alt="Dark gray" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fcd%2F7b%2Fcd7b894fba8c32078439f442e205ef9d719e8fb0.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Dark gray" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fcd%2F7b%2Fcd7b894fba8c32078439f442e205ef9d719e8fb0.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>]

# %%
soup.find_all('a', 'filter-option miniature')[0].get('data-color')
# Out:
# 'Light denim blue'

# %%
product_list = soup.find_all('a', 'filter-option miniature')

#cor
product_color = [p.get('data-color') for p in product_list] 

#id
product_id = [p.get('data-articlecode') for p in product_list]

# %%
product_color
# Out:
# ['Light denim blue',
#  'Light denim blue',
#  'Denim blue',
#  'Dark blue',
#  'Dark denim blue',
#  'Dark gray']

# %%
product_id
# Out:
# ['1024256002',
#  '1024256003',
#  '1024256004',
#  '1024256005',
#  '1024256006',
#  '1024256007']

# %%
df_color = pd.DataFrame([product_id, product_color]).T
df_color.columns = ['id', 'color']
df_color
# Out:
#            id             color
# 0  1024256002  Light denim blue
# 1  1024256003  Light denim blue
# 2  1024256004        Denim blue
# 3  1024256005         Dark blue
# 4  1024256006   Dark denim blue
# 5  1024256007         Dark gray

# %%
#Generate style ID + color ID
df_color['style_id'] = df_color['id'].apply(lambda x: x[:-3])
df_color['color_id'] = df_color['id'].apply(lambda x: x[-3:])
df_color
# Out:
#            id             color style_id color_id
# 0  1024256002  Light denim blue  1024256      002
# 1  1024256003  Light denim blue  1024256      003
# 2  1024256004        Denim blue  1024256      004
# 3  1024256005         Dark blue  1024256      005
# 4  1024256006   Dark denim blue  1024256      006
# 5  1024256007         Dark gray  1024256      007

# %% [markdown]
# #### Filtrando por material/composition

# %% [markdown]
# O material só pode ser filtrado na página do produto e não na vitrine.

# %%
url = "https://www2.hm.com/en_us/productpage.1024256001.html"

# conteúdo de headers é padrão
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
page = requests.get(url, headers=headers)

soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup.find_all('div', 'content pdp-text pdp-content')
# Out:
# [<div class="content pdp-text pdp-content">
#  <p class="pdp-description-text">5-pocket jeans in stretch cotton denim. Regular waist, zip fly with button, and slim legs.</p>
#  <dl class="pdp-description-list">
#  <div class="pdp-description-list-item">
#  <dt>Size</dt>
#  <dd>The model is 185cm/6'1" and wears a size 31/32</dd>
#  </div>
#  <div class="pdp-description-list-item">
#  <dt>Fit</dt>
#  <dd>
#  <ul>
#  <li>Slim fit</li>
#  </ul>
#  </dd>
#  </div>
#  <div class="pdp-description-list-item">
#  <dt>Composition</dt>
#  <dd>
#  <ul>
#  <li>Pocket lining: Polyester 65%, Cotton 35%</li>
#  <li>Shell: Cotton 99%, Spandex 1%</li>
#  </ul>
#  </dd>
#  </div>
#  <!--WARNINGS-->
#  <!--ARTICLE NUMBER-->
#  <div class="pdp-description-list-item">
#  <dt>Art. No.</dt>
#  <dd>1024256001</dd>
#  </div>
#  </dl>
#  <!-- / pdp-description-list -->
#  <section class="review-answers selected-rating" id="js-selected-rating"></section>
#  <!-- / pdp-true-to-size -->
#  </div>]

# %%
soup.find_all('div', 'pdp-description-list-item')
# Out:
# [<div class="pdp-description-list-item">
#  <dt>Size</dt>
#  <dd>The model is 185cm/6'1" and wears a size 31/32</dd>
#  </div>,
#  <div class="pdp-description-list-item">
#  <dt>Fit</dt>
#  <dd>
#  <ul>
#  <li>Slim fit</li>
#  </ul>
#  </dd>
#  </div>,
#  <div class="pdp-description-list-item">
#  <dt>Composition</dt>
#  <dd>
#  <ul>
#  <li>Pocket lining: Polyester 65%, Cotton 35%</li>
#  <li>Shell: Cotton 99%, Spandex 1%</li>
#  </ul>
#  </dd>
#  </div>,
#  <div class="pdp-description-list-item">
#  <dt>Art. No.</dt>
#  <dd>1024256001</dd>
#  </div>]

# %%
soup.find_all('div', 'pdp-description-list-item')[1]
# Out:
# <div class="pdp-description-list-item">
# <dt>Fit</dt>
# <dd>
# <ul>
# <li>Slim fit</li>
# </ul>
# </dd>
# </div>

# %%
type(soup.find_all('div', 'pdp-description-list-item')[1])
# Out:
# bs4.element.Tag

# %%
soup.find_all('div', 'pdp-description-list-item')[1].get_text()
# Out:
# '\nFit\n\n\nSlim fit\n\n\n'

# %%
type(soup.find_all('div', 'pdp-description-list-item')[1].get_text())
# Out:
# str

# %%
soup.find_all('div', 'pdp-description-list-item')[1].get_text().split('\n')
# Out:
# ['', 'Fit', '', '', 'Slim fit', '', '', '']

# %%
filter( None, soup.find_all('div', 'pdp-description-list-item')[1].get_text().split('\n'))

# %%
list(filter( None, soup.find_all('div', 'pdp-description-list-item')[1].get_text().split('\n')))
# Out:
# ['Fit', 'Slim fit']

# %%
product_composition_list = soup.find_all('div', 'pdp-description-list-item')

product_composition = [list( filter( None, p.get_text().split('\n') ) ) for p in product_composition_list]

# %%
product_composition
# Out:
# [['Size', 'The model is 185cm/6\'1" and wears a size 31/32'],
#  ['Fit', 'Slim fit'],
#  ['Composition',
#   'Pocket lining: Polyester 65%, Cotton 35%',
#   'Shell: Cotton 99%, Spandex 1%'],
#  ['Art. No.', '1024256001']]

# %%
product_composition.pop(0)
product_composition
# Out:
# [['Fit', 'Slim fit'],
#  ['Composition',
#   'Pocket lining: Polyester 65%, Cotton 35%',
#   'Shell: Cotton 99%, Spandex 1%'],
#  ['Art. No.', '1024256001']]

# %%
pd.DataFrame(product_composition).T
# Out:
#           0                                         1           2
# 0       Fit                               Composition    Art. No.
# 1  Slim fit  Pocket lining: Polyester 65%, Cotton 35%  1024256001
# 2      None             Shell: Cotton 99%, Spandex 1%        None

# %%
df_aux = pd.DataFrame(product_composition).T
df_aux
# Out:
#           0                                         1           2
# 0       Fit                               Composition    Art. No.
# 1  Slim fit  Pocket lining: Polyester 65%, Cotton 35%  1024256001
# 2      None             Shell: Cotton 99%, Spandex 1%        None

# %%
df_aux.columns = df_aux.iloc[0]
df_aux
# Out:
# 0       Fit                               Composition    Art. No.
# 0       Fit                               Composition    Art. No.
# 1  Slim fit  Pocket lining: Polyester 65%, Cotton 35%  1024256001
# 2      None             Shell: Cotton 99%, Spandex 1%        None

# %%
df_aux = df_aux.iloc[1:].fillna(method='ffill')
df_aux
# Out:
# 0       Fit                               Composition    Art. No.
# 1  Slim fit  Pocket lining: Polyester 65%, Cotton 35%  1024256001
# 2  Slim fit             Shell: Cotton 99%, Spandex 1%  1024256001

# %% [markdown]
# Style ID
#
#       -> Product ID
#         -> Color ID
#           -> SKU
#
#       Style ID + Color ID -> Product ID
#       Style ID + Color ID + Size ID => SKU

# %%
# Generate Style ID + Color ID
# All values, but the last three values
df_aux['style_id'] = df_aux['Art. No.'].apply(lambda x: x[:-3])

df_aux['color_id'] = df_aux['Art. No.'].apply(lambda x: x[-3:])

# %%
df_aux
# Out:
# 0       Fit                               Composition    Art. No. style_id  \
# 1  Slim fit  Pocket lining: Polyester 65%, Cotton 35%  1024256001  1024256
# 2  Slim fit             Shell: Cotton 99%, Spandex 1%  1024256001  1024256
#
# 0 color_id
# 1      001
# 2      001

# %% [markdown]
# #### Mesclando as células

# %%
pd.merge(df_color, df_aux[['style_id', 'Fit', 'Composition']], how='left', on='style_id')
# Out:
#             id             color style_id color_id       Fit  \
# 0   1024256002  Light denim blue  1024256      002  Slim fit
# 1   1024256002  Light denim blue  1024256      002  Slim fit
# 2   1024256003  Light denim blue  1024256      003  Slim fit
# 3   1024256003  Light denim blue  1024256      003  Slim fit
# 4   1024256004        Denim blue  1024256      004  Slim fit
# 5   1024256004        Denim blue  1024256      004  Slim fit
# 6   1024256005         Dark blue  1024256      005  Slim fit
# 7   1024256005         Dark blue  1024256      005  Slim fit
# 8   1024256006   Dark denim blue  1024256      006  Slim fit
# 9   1024256006   Dark denim blue  1024256      006  Slim fit
# 10  1024256007         Dark gray  1024256      007  Slim fit
# 11  1024256007         Dark gray  1024256      007  Slim fit
#
#                                  Composition
# 0   Pocket lining: Polyester 65%, Cotton 35%
# 1              Shell: Cotton 99%, Spandex 1%
# 2   Pocket lining: Polyester 65%, Cotton 35%
# 3              Shell: Cotton 99%, Spandex 1%
# 4   Pocket lining: Polyester 65%, Cotton 35%
# 5              Shell: Cotton 99%, Spandex 1%
# 6   Pocket lining: Polyester 65%, Cotton 35%
# 7              Shell: Cotton 99%, Spandex 1%
# 8   Pocket lining: Polyester 65%, Cotton 35%
# 9              Shell: Cotton 99%, Spandex 1%
# 10  Pocket lining: Polyester 65%, Cotton 35%
# 11             Shell: Cotton 99%, Spandex 1%

# %%
data_merge = pd.merge(df_color, df_aux[['style_id', 'Fit', 'Composition']], how='left', on='style_id')

# %% [markdown]
# # Único comando para coleta de cor e composição

# %%
#API request
# conteúdo de headers é padrão
url = "https://www2.hm.com/en_us/productpage.1024256001.html"

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
page = requests.get(url, headers=headers)

#Beautiful Soup object
soup = BeautifulSoup(page.text, 'html.parser')

# ============================= Color =========================

#product list
product_list = soup.find_all('a', 'filter-option miniature')

#color
product_color = [p.get('data-color') for p in product_list] 

#id
product_id = [p.get('data-articlecode') for p in product_list]

#dataframe
df_color = pd.DataFrame([product_id, product_color]).T
df_color.columns = ['id', 'color']

#generate style id + color id
df_color['style_id'] = df_color['id'].apply(lambda x: x[:-3])
df_color['color_id'] = df_color['id'].apply(lambda x: x[-3:])

# ============================ Composition =====================

# Product list
product_composition_list = soup.find_all('div', 'pdp-description-list-item')

# Composition
product_composition = [list( filter( None, p.get_text().split('\n') ) ) for p in product_composition_list]

# Deleting row
product_composition.pop(0)

# dataframe
df_composition = pd.DataFrame(product_composition).T

# Columns name
df_composition.columns = df_composition.iloc[0]

# Filling None/NA values
df_composition = df_composition.iloc[1:].fillna(method='ffill')

# Generate Style ID + Color ID
# All values, but the last three values
df_composition['style_id'] = df_composition['Art. No.'].apply(lambda x: x[:-3])
df_composition['color_id'] = df_composition['Art. No.'].apply(lambda x: x[-3:])

# ======================= Merging color + composition ==========================
data_merge = pd.merge(df_color, df_composition[['style_id', 'Fit', 'Composition']], how='left', on='style_id')

# %%
data_merge
# Out:
#             id             color style_id color_id       Fit  \
# 0   1024256002  Light denim blue  1024256      002  Slim fit
# 1   1024256002  Light denim blue  1024256      002  Slim fit
# 2   1024256003  Light denim blue  1024256      003  Slim fit
# 3   1024256003  Light denim blue  1024256      003  Slim fit
# 4   1024256004        Denim blue  1024256      004  Slim fit
# 5   1024256004        Denim blue  1024256      004  Slim fit
# 6   1024256005         Dark blue  1024256      005  Slim fit
# 7   1024256005         Dark blue  1024256      005  Slim fit
# 8   1024256006   Dark denim blue  1024256      006  Slim fit
# 9   1024256006   Dark denim blue  1024256      006  Slim fit
# 10  1024256007         Dark gray  1024256      007  Slim fit
# 11  1024256007         Dark gray  1024256      007  Slim fit
#
#                                  Composition
# 0   Pocket lining: Polyester 65%, Cotton 35%
# 1              Shell: Cotton 99%, Spandex 1%
# 2   Pocket lining: Polyester 65%, Cotton 35%
# 3              Shell: Cotton 99%, Spandex 1%
# 4   Pocket lining: Polyester 65%, Cotton 35%
# 5              Shell: Cotton 99%, Spandex 1%
# 6   Pocket lining: Polyester 65%, Cotton 35%
# 7              Shell: Cotton 99%, Spandex 1%
# 8   Pocket lining: Polyester 65%, Cotton 35%
# 9              Shell: Cotton 99%, Spandex 1%
# 10  Pocket lining: Polyester 65%, Cotton 35%
# 11             Shell: Cotton 99%, Spandex 1%

# %% [markdown]
# # Multiple Products

# %% [markdown]
# Vamos coletar as cores e a composição de cada produto da vitrine, conforme cada id.

# %%
data
# Out:
#             id                          product_name       product_type  \
# 0   1024256001                            Slim Jeans     men_jeans_slim
# 1   1024256003                            Slim Jeans     men_jeans_slim
# 2   0690449056                          Skinny Jeans   men_jeans_ripped
# 3   0985159001                          Skinny Jeans   men_jeans_skinny
# 4   0690449022                          Skinny Jeans   men_jeans_ripped
# 5   1024256004                            Slim Jeans     men_jeans_slim
# 6   1024256007                            Slim Jeans     men_jeans_slim
# 7   0690449051                          Skinny Jeans   men_jeans_ripped
# 8   0690449043                          Skinny Jeans   men_jeans_ripped
# 9   0690449036                          Skinny Jeans   men_jeans_ripped
# 10  0875105016                         Relaxed Jeans  men_jeans_relaxed
# 11  1013317001        Hybrid Regular Tapered Joggers  men_jeans_regular
# 12  1004199005                  Skinny Cropped Jeans   men_jeans_skinny
# 13  0985159004                          Skinny Jeans   men_jeans_skinny
# 14  0875105023                         Relaxed Jeans  men_jeans_relaxed
# 15  0985159005                          Skinny Jeans   men_jeans_skinny
# 16  1008110001                   Freefit® Slim Jeans     men_jeans_slim
# 17  1004199002                  Skinny Cropped Jeans   men_jeans_skinny
# 18  0985159008                          Skinny Jeans   men_jeans_skinny
# 19  1024711001                            Slim Jeans     men_jeans_slim
# 20  0875105018                         Relaxed Jeans  men_jeans_relaxed
# 21  1013317008        Hybrid Regular Tapered Joggers  men_jeans_regular
# 22  0974202003                 Regular Denim Joggers    men_jeans_loose
# 23  1013317006        Hybrid Regular Tapered Joggers  men_jeans_regular
# 24  0875105024                         Relaxed Jeans  men_jeans_relaxed
# 25  0938875014                    Slim Tapered Jeans     men_jeans_slim
# 26  1008549002                         Regular Jeans  men_jeans_regular
# 27  1024256006                            Slim Jeans     men_jeans_slim
# 28  1013317010        Hybrid Regular Tapered Joggers  men_jeans_regular
# 29  0993887004          Hybrid Regular Denim Joggers  men_jeans_regular
# 30  1013317002        Hybrid Regular Tapered Joggers  men_jeans_regular
# 31  0985159002                          Skinny Jeans   men_jeans_skinny
# 32  1028865001  Relaxed Jeans with Embroidery Detail  men_jeans_relaxed
# 33  0938875007                    Slim Tapered Jeans     men_jeans_slim
# 34  1008110003                   Freefit® Slim Jeans     men_jeans_slim
# 35  0985197001                            Slim Jeans     men_jeans_slim
#
#       price             datetime
# 0   $ 19.99  2022-01-24 14:43:08
# 1   $ 19.99  2022-01-24 14:43:08
# 2   $ 39.99  2022-01-24 14:43:08
# 3   $ 24.99  2022-01-24 14:43:08
# 4   $ 39.99  2022-01-24 14:43:08
# 5   $ 19.99  2022-01-24 14:43:08
# 6   $ 19.99  2022-01-24 14:43:08
# 7   $ 39.99  2022-01-24 14:43:08
# 8   $ 39.99  2022-01-24 14:43:08
# 9   $ 39.99  2022-01-24 14:43:08
# 10  $ 34.99  2022-01-24 14:43:08
# 11  $ 39.99  2022-01-24 14:43:08
# 12  $ 29.99  2022-01-24 14:43:08
# 13  $ 24.99  2022-01-24 14:43:08
# 14  $ 34.99  2022-01-24 14:43:08
# 15  $ 24.99  2022-01-24 14:43:08
# 16  $ 59.99  2022-01-24 14:43:08
# 17  $ 29.99  2022-01-24 14:43:08
# 18  $ 24.99  2022-01-24 14:43:08
# 19  $ 29.99  2022-01-24 14:43:08
# 20  $ 34.99  2022-01-24 14:43:08
# 21  $ 39.99  2022-01-24 14:43:08
# 22  $ 29.99  2022-01-24 14:43:08
# 23  $ 39.99  2022-01-24 14:43:08
# 24  $ 34.99  2022-01-24 14:43:08
# 25  $ 39.99  2022-01-24 14:43:08
# 26  $ 24.99  2022-01-24 14:43:08
# 27  $ 19.99  2022-01-24 14:43:08
# 28  $ 39.99  2022-01-24 14:43:08
# 29  $ 44.99  2022-01-24 14:43:08
# 30  $ 39.99  2022-01-24 14:43:08
# 31  $ 24.99  2022-01-24 14:43:08
# 32  $ 49.99  2022-01-24 14:43:08
# 33  $ 39.99  2022-01-24 14:43:08
# 34  $ 59.99  2022-01-24 14:43:08
# 35  $ 19.99  2022-01-24 14:43:08

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

#empty dataframe
df_final = pd.DataFrame()

for i in range(len(data)):

    #API request
    # conteúdo de headers é padrão
    url = "https://www2.hm.com/en_us/productpage." + data.loc[i, 'id'] + ".html"

    page = requests.get(url, headers=headers)

    #Beautiful Soup object
    soup = BeautifulSoup(page.text, 'html.parser')

    # ============================= Color =========================

    #product list
    product_list = soup.find_all('a', 'filter-option miniature')

    #color
    product_color = [p.get('data-color') for p in product_list] 

    #id
    product_id = [p.get('data-articlecode') for p in product_list]

    #dataframe
    df_color = pd.DataFrame([product_id, product_color]).T
    df_color.columns = ['id', 'color']

    #generate style id + color id
    df_color['style_id'] = df_color['id'].apply(lambda x: x[:-3])
    df_color['color_id'] = df_color['id'].apply(lambda x: x[-3:])

    # ============================ Composition =====================

    # Product list
    product_composition_list = soup.find_all('div', 'pdp-description-list-item')

    # Composition
    product_composition = [list( filter( None, p.get_text().split('\n') ) ) for p in product_composition_list]

  
    # dataframe
    df_composition = pd.DataFrame(product_composition).T

    # Columns name
    df_composition.columns = df_composition.iloc[0]

    # Filling None/NA values
    df_composition = df_composition.iloc[1:].fillna(method='ffill')

    # Generate Style ID + Color ID
    # All values, but the last three values
    df_composition['style_id'] = df_composition['Art. No.'].apply(lambda x: x[:-3])
    df_composition['color_id'] = df_composition['Art. No.'].apply(lambda x: x[-3:])

    # ======================= Merging color + composition ==========================
    data_merge = pd.merge(df_color, df_composition[['style_id', 'Fit', 'Composition']], how='left', on='style_id')

    # ======================= Concatenate ==========================================
    df_final = pd.concat( [df_final, data_merge], axis=0 )

# %%
df_final
# Out:
#             id             color style_id color_id       Fit  \
# 0   1024256002  Light denim blue  1024256      002  Slim fit
# 1   1024256002  Light denim blue  1024256      002  Slim fit
# 2   1024256003  Light denim blue  1024256      003  Slim fit
# 3   1024256003  Light denim blue  1024256      003  Slim fit
# 4   1024256004        Denim blue  1024256      004  Slim fit
# ..         ...               ...      ...      ...       ...
# 7   0985197005   Dark denim blue  0985197      005  Slim fit
# 8   0985197006  Light denim blue  0985197      006  Slim fit
# 9   0985197006  Light denim blue  0985197      006  Slim fit
# 10  0985197007         Dark gray  0985197      007  Slim fit
# 11  0985197007         Dark gray  0985197      007  Slim fit
#
#                                  Composition
# 0   Pocket lining: Polyester 65%, Cotton 35%
# 1              Shell: Cotton 99%, Spandex 1%
# 2   Pocket lining: Polyester 65%, Cotton 35%
# 3              Shell: Cotton 99%, Spandex 1%
# 4   Pocket lining: Polyester 65%, Cotton 35%
# ..                                       ...
# 7              Shell: Cotton 98%, Spandex 2%
# 8                 Pocket lining: Cotton 100%
# 9              Shell: Cotton 98%, Spandex 2%
# 10                Pocket lining: Cotton 100%
# 11             Shell: Cotton 98%, Spandex 2%
#
# [457 rows x 6 columns]

# %% [markdown]
# # Multiple products incluindo a coluna Size e outras que estiverem no catálogo

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

#empty dataframe
df_final = pd.DataFrame()

# Unique columns for all products
aux = []

for i in range(len(data)):

    #API request
    # conteúdo de headers é padrão
    url = "https://www2.hm.com/en_us/productpage." + data.loc[i, 'id'] + ".html"

    page = requests.get(url, headers=headers)

    #Beautiful Soup object
    soup = BeautifulSoup(page.text, 'html.parser')

    # ============================= Color =========================

    #product list
    product_list = soup.find_all('a', 'filter-option miniature')

    #color
    product_color = [p.get('data-color') for p in product_list] 

    #id
    product_id = [p.get('data-articlecode') for p in product_list]

    #dataframe
    df_color = pd.DataFrame([product_id, product_color]).T
    df_color.columns = ['id', 'color']

    #generate style id + color id
    df_color['style_id'] = df_color['id'].apply(lambda x: x[:-3])
    df_color['color_id'] = df_color['id'].apply(lambda x: x[-3:])

    # ============================ Composition =====================

    # Product list
    product_composition_list = soup.find_all('div', 'pdp-description-list-item')

    # Composition
    product_composition = [list( filter( None, p.get_text().split('\n') ) ) for p in product_composition_list]

  
    # dataframe
    df_composition = pd.DataFrame(product_composition).T

    # Columns name
    df_composition.columns = df_composition.iloc[0]

    # Filling None/NA values
    df_composition = df_composition.iloc[1:].fillna(method='ffill')

    # Generate Style ID + Color ID
    # All values, but the last three values
    df_composition['style_id'] = df_composition['Art. No.'].apply(lambda x: x[:-3])
    df_composition['color_id'] = df_composition['Art. No.'].apply(lambda x: x[-3:])

    # ========== Columns we want
    aux = aux + df_composition.columns.tolist()
    
    # ======================= Merging color + composition ==========================
    data_merge = pd.merge(df_color, df_composition[['style_id', 'Fit', 'Composition']], how='left', on='style_id')

    # ======================= Concatenate ==========================================
    df_final = pd.concat( [df_final, data_merge], axis=0 )

# %%
aux
# Out:
# ['Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'More sustainable materials',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Fit',
#  'Composition',
#  'More sustainable materials',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Fit',
#  'Composition',
#  'More sustainable materials',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'More sustainable materials',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'More sustainable materials',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'More sustainable materials',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'More sustainable materials',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'More sustainable materials',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Fit',
#  'Composition',
#  'More sustainable materials',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Fit',
#  'Composition',
#  'More sustainable materials',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'More sustainable materials',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'More sustainable materials',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id',
#  'Size',
#  'Fit',
#  'Composition',
#  'Art. No.',
#  'style_id',
#  'color_id']

# %%
set(aux)
# Out:
# {'Art. No.',
#  'Composition',
#  'Fit',
#  'More sustainable materials',
#  'Size',
#  'color_id',
#  'style_id'}

# %% [markdown]
# Agora vamos criar uma lista com todas as possíveis colunas da vitrine:

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

#empty dataframe
df_final = pd.DataFrame()

# All columns found on website
cols = ['Art. No.', 'Composition', 'Fit', 'More sustainable materials', 'Size']
df_pattern = pd.DataFrame(columns=cols)

for i in range(len(data)):

    #API request
    # conteúdo de headers é padrão
    url = "https://www2.hm.com/en_us/productpage." + data.loc[i, 'id'] + ".html"

    page = requests.get(url, headers=headers)

    #Beautiful Soup object
    soup = BeautifulSoup(page.text, 'html.parser')

    # ============================= Color =========================

    #product list
    product_list = soup.find_all('a', 'filter-option miniature')

    #color
    product_color = [p.get('data-color') for p in product_list] 

    #id
    product_id = [p.get('data-articlecode') for p in product_list]

    #dataframe
    df_color = pd.DataFrame([product_id, product_color]).T
    df_color.columns = ['id', 'color']

    #generate style id + color id
    df_color['style_id'] = df_color['id'].apply(lambda x: x[:-3])
    df_color['color_id'] = df_color['id'].apply(lambda x: x[-3:])

    # ============================ Composition =====================

    # Product list
    product_composition_list = soup.find_all('div', 'pdp-description-list-item')

    # Composition
    product_composition = [list( filter( None, p.get_text().split('\n') ) ) for p in product_composition_list]

  
    # dataframe
    df_composition = pd.DataFrame(product_composition).T

    # Columns name
    df_composition.columns = df_composition.iloc[0]

    # Filling None/NA values
    df_composition = df_composition.iloc[1:].fillna(method='ffill')

    # The same number of columns (pattern)
    df_composition = pd.concat( [df_pattern, df_composition] )
    
    # Generate Style ID + Color ID
    # All values, but the last three values
    df_composition['style_id'] = df_composition['Art. No.'].apply(lambda x: x[:-3])
    df_composition['color_id'] = df_composition['Art. No.'].apply(lambda x: x[-3:])
    
    # ======================= Merging color + composition ==========================
    data_merge = pd.merge(df_color, df_composition[['style_id', 'Fit', 'Composition', 'More sustainable materials', 'Size']], how='left', on='style_id')

    # ======================= Concatenate ==========================================
    df_final = pd.concat( [df_final, data_merge], axis=0 )

# %%
df_final
# Out:
#             id             color style_id color_id       Fit  \
# 0   1024256002  Light denim blue  1024256      002  Slim fit
# 1   1024256002  Light denim blue  1024256      002  Slim fit
# 2   1024256003  Light denim blue  1024256      003  Slim fit
# 3   1024256003  Light denim blue  1024256      003  Slim fit
# 4   1024256004        Denim blue  1024256      004  Slim fit
# ..         ...               ...      ...      ...       ...
# 7   0985197005   Dark denim blue  0985197      005  Slim fit
# 8   0985197006  Light denim blue  0985197      006  Slim fit
# 9   0985197006  Light denim blue  0985197      006  Slim fit
# 10  0985197007         Dark gray  0985197      007  Slim fit
# 11  0985197007         Dark gray  0985197      007  Slim fit
#
#                                  Composition More sustainable materials  \
# 0   Pocket lining: Polyester 65%, Cotton 35%                        NaN
# 1              Shell: Cotton 99%, Spandex 1%                        NaN
# 2   Pocket lining: Polyester 65%, Cotton 35%                        NaN
# 3              Shell: Cotton 99%, Spandex 1%                        NaN
# 4   Pocket lining: Polyester 65%, Cotton 35%                        NaN
# ..                                       ...                        ...
# 7              Shell: Cotton 98%, Spandex 2%                        NaN
# 8                 Pocket lining: Cotton 100%                        NaN
# 9              Shell: Cotton 98%, Spandex 2%                        NaN
# 10                Pocket lining: Cotton 100%                        NaN
# 11             Shell: Cotton 98%, Spandex 2%                        NaN
#
#                                               Size
# 0   The model is 185cm/6'1" and wears a size 31/32
# 1   The model is 185cm/6'1" and wears a size 31/32
# 2   The model is 185cm/6'1" and wears a size 31/32
# 3   The model is 185cm/6'1" and wears a size 31/32
# 4   The model is 185cm/6'1" and wears a size 31/32
# ..                                             ...
# 7   The model is 189cm/6'2" and wears a size 32/32
# 8   The model is 189cm/6'2" and wears a size 32/32
# 9   The model is 189cm/6'2" and wears a size 32/32
# 10  The model is 189cm/6'2" and wears a size 32/32
# 11  The model is 189cm/6'2" and wears a size 32/32
#
# [457 rows x 8 columns]

# %% [markdown]
# # Juntando todos os dados

# %%
data
# Out:
#             id                          product_name       product_type  \
# 0   1024256001                            Slim Jeans     men_jeans_slim
# 1   1024256003                            Slim Jeans     men_jeans_slim
# 2   0690449056                          Skinny Jeans   men_jeans_ripped
# 3   0985159001                          Skinny Jeans   men_jeans_skinny
# 4   0690449022                          Skinny Jeans   men_jeans_ripped
# 5   1024256004                            Slim Jeans     men_jeans_slim
# 6   1024256007                            Slim Jeans     men_jeans_slim
# 7   0690449051                          Skinny Jeans   men_jeans_ripped
# 8   0690449043                          Skinny Jeans   men_jeans_ripped
# 9   0690449036                          Skinny Jeans   men_jeans_ripped
# 10  0875105016                         Relaxed Jeans  men_jeans_relaxed
# 11  1013317001        Hybrid Regular Tapered Joggers  men_jeans_regular
# 12  1004199005                  Skinny Cropped Jeans   men_jeans_skinny
# 13  0985159004                          Skinny Jeans   men_jeans_skinny
# 14  0875105023                         Relaxed Jeans  men_jeans_relaxed
# 15  0985159005                          Skinny Jeans   men_jeans_skinny
# 16  1008110001                   Freefit® Slim Jeans     men_jeans_slim
# 17  1004199002                  Skinny Cropped Jeans   men_jeans_skinny
# 18  0985159008                          Skinny Jeans   men_jeans_skinny
# 19  1024711001                            Slim Jeans     men_jeans_slim
# 20  0875105018                         Relaxed Jeans  men_jeans_relaxed
# 21  1013317008        Hybrid Regular Tapered Joggers  men_jeans_regular
# 22  0974202003                 Regular Denim Joggers    men_jeans_loose
# 23  1013317006        Hybrid Regular Tapered Joggers  men_jeans_regular
# 24  0875105024                         Relaxed Jeans  men_jeans_relaxed
# 25  0938875014                    Slim Tapered Jeans     men_jeans_slim
# 26  1008549002                         Regular Jeans  men_jeans_regular
# 27  1024256006                            Slim Jeans     men_jeans_slim
# 28  1013317010        Hybrid Regular Tapered Joggers  men_jeans_regular
# 29  0993887004          Hybrid Regular Denim Joggers  men_jeans_regular
# 30  1013317002        Hybrid Regular Tapered Joggers  men_jeans_regular
# 31  0985159002                          Skinny Jeans   men_jeans_skinny
# 32  1028865001  Relaxed Jeans with Embroidery Detail  men_jeans_relaxed
# 33  0938875007                    Slim Tapered Jeans     men_jeans_slim
# 34  1008110003                   Freefit® Slim Jeans     men_jeans_slim
# 35  0985197001                            Slim Jeans     men_jeans_slim
#
#       price             datetime
# 0   $ 19.99  2022-01-24 14:43:08
# 1   $ 19.99  2022-01-24 14:43:08
# 2   $ 39.99  2022-01-24 14:43:08
# 3   $ 24.99  2022-01-24 14:43:08
# 4   $ 39.99  2022-01-24 14:43:08
# 5   $ 19.99  2022-01-24 14:43:08
# 6   $ 19.99  2022-01-24 14:43:08
# 7   $ 39.99  2022-01-24 14:43:08
# 8   $ 39.99  2022-01-24 14:43:08
# 9   $ 39.99  2022-01-24 14:43:08
# 10  $ 34.99  2022-01-24 14:43:08
# 11  $ 39.99  2022-01-24 14:43:08
# 12  $ 29.99  2022-01-24 14:43:08
# 13  $ 24.99  2022-01-24 14:43:08
# 14  $ 34.99  2022-01-24 14:43:08
# 15  $ 24.99  2022-01-24 14:43:08
# 16  $ 59.99  2022-01-24 14:43:08
# 17  $ 29.99  2022-01-24 14:43:08
# 18  $ 24.99  2022-01-24 14:43:08
# 19  $ 29.99  2022-01-24 14:43:08
# 20  $ 34.99  2022-01-24 14:43:08
# 21  $ 39.99  2022-01-24 14:43:08
# 22  $ 29.99  2022-01-24 14:43:08
# 23  $ 39.99  2022-01-24 14:43:08
# 24  $ 34.99  2022-01-24 14:43:08
# 25  $ 39.99  2022-01-24 14:43:08
# 26  $ 24.99  2022-01-24 14:43:08
# 27  $ 19.99  2022-01-24 14:43:08
# 28  $ 39.99  2022-01-24 14:43:08
# 29  $ 44.99  2022-01-24 14:43:08
# 30  $ 39.99  2022-01-24 14:43:08
# 31  $ 24.99  2022-01-24 14:43:08
# 32  $ 49.99  2022-01-24 14:43:08
# 33  $ 39.99  2022-01-24 14:43:08
# 34  $ 59.99  2022-01-24 14:43:08
# 35  $ 19.99  2022-01-24 14:43:08

# %%
# Creating style_id + color_id
data['style_id'] = data['id'].apply(lambda x: x[:-3])
data['color_id'] = data['id'].apply(lambda x: x[-3:])

data_raw = pd.merge( data, df_final[['color', 'style_id', 'Fit', 'Composition', 'More sustainable materials', 'Size']], how='left', on='style_id')

# %%
data_raw.head()
# Out:
#            id product_name    product_type    price             datetime  \
# 0  1024256001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# 1  1024256001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# 2  1024256001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# 3  1024256001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# 4  1024256001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
#
#   style_id color_id             color       Fit  \
# 0  1024256      001  Light denim blue  Slim fit
# 1  1024256      001  Light denim blue  Slim fit
# 2  1024256      001  Light denim blue  Slim fit
# 3  1024256      001  Light denim blue  Slim fit
# 4  1024256      001        Denim blue  Slim fit
#
#                                 Composition More sustainable materials  \
# 0  Pocket lining: Polyester 65%, Cotton 35%                        NaN
# 1             Shell: Cotton 99%, Spandex 1%                        NaN
# 2  Pocket lining: Polyester 65%, Cotton 35%                        NaN
# 3             Shell: Cotton 99%, Spandex 1%                        NaN
# 4  Pocket lining: Polyester 65%, Cotton 35%                        NaN
#
#                                              Size
# 0  The model is 185cm/6'1" and wears a size 31/32
# 1  The model is 185cm/6'1" and wears a size 31/32
# 2  The model is 185cm/6'1" and wears a size 31/32
# 3  The model is 185cm/6'1" and wears a size 31/32
# 4  The model is 185cm/6'1" and wears a size 31/32

# %%
data_raw
# Out:
#               id product_name    product_type    price             datetime  \
# 0     1024256001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# 1     1024256001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# 2     1024256001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# 3     1024256001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# 4     1024256001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# ...          ...          ...             ...      ...                  ...
# 1950  0985197001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# 1951  0985197001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# 1952  0985197001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# 1953  0985197001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
# 1954  0985197001   Slim Jeans  men_jeans_slim  $ 19.99  2022-01-24 14:43:08
#
#      style_id color_id             color       Fit  \
# 0     1024256      001  Light denim blue  Slim fit
# 1     1024256      001  Light denim blue  Slim fit
# 2     1024256      001  Light denim blue  Slim fit
# 3     1024256      001  Light denim blue  Slim fit
# 4     1024256      001        Denim blue  Slim fit
# ...       ...      ...               ...       ...
# 1950  0985197      001   Dark denim blue  Slim fit
# 1951  0985197      001  Light denim blue  Slim fit
# 1952  0985197      001  Light denim blue  Slim fit
# 1953  0985197      001         Dark gray  Slim fit
# 1954  0985197      001         Dark gray  Slim fit
#
#                                    Composition More sustainable materials  \
# 0     Pocket lining: Polyester 65%, Cotton 35%                        NaN
# 1                Shell: Cotton 99%, Spandex 1%                        NaN
# 2     Pocket lining: Polyester 65%, Cotton 35%                        NaN
# 3                Shell: Cotton 99%, Spandex 1%                        NaN
# 4     Pocket lining: Polyester 65%, Cotton 35%                        NaN
# ...                                        ...                        ...
# 1950             Shell: Cotton 98%, Spandex 2%                        NaN
# 1951                Pocket lining: Cotton 100%                        NaN
# 1952             Shell: Cotton 98%, Spandex 2%                        NaN
# 1953                Pocket lining: Cotton 100%                        NaN
# 1954             Shell: Cotton 98%, Spandex 2%                        NaN
#
#                                                 Size
# 0     The model is 185cm/6'1" and wears a size 31/32
# 1     The model is 185cm/6'1" and wears a size 31/32
# 2     The model is 185cm/6'1" and wears a size 31/32
# 3     The model is 185cm/6'1" and wears a size 31/32
# 4     The model is 185cm/6'1" and wears a size 31/32
# ...                                              ...
# 1950  The model is 189cm/6'2" and wears a size 32/32
# 1951  The model is 189cm/6'2" and wears a size 32/32
# 1952  The model is 189cm/6'2" and wears a size 32/32
# 1953  The model is 189cm/6'2" and wears a size 32/32
# 1954  The model is 189cm/6'2" and wears a size 32/32
#
# [1955 rows x 12 columns]

# %% [markdown]
# # Page size total (toda a vitrine/ todas as páginas/paginação)

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

#empty dataframe
df_final = pd.DataFrame()

# All columns found on website
cols = ['Art. No.', 'Composition', 'Fit', 'More sustainable materials', 'Size']
df_pattern = pd.DataFrame(columns=cols)

for i in range(len(data)):

    #API request
    # conteúdo de headers é padrão
    url = "https://www2.hm.com/en_us/productpage." + data.loc[i, 'id'] + ".html"+ "?page-size=" + str(int(pagination_number*36))

    page = requests.get(url, headers=headers)

    #Beautiful Soup object
    soup = BeautifulSoup(page.text, 'html.parser')

    # ============================= Color =========================

    #product list
    product_list = soup.find_all('a', 'filter-option miniature')

    #color
    product_color = [p.get('data-color') for p in product_list] 

    #id
    product_id = [p.get('data-articlecode') for p in product_list]

    #dataframe
    df_color = pd.DataFrame([product_id, product_color]).T
    df_color.columns = ['id', 'color']

    #generate style id + color id
    df_color['style_id'] = df_color['id'].apply(lambda x: x[:-3])
    df_color['color_id'] = df_color['id'].apply(lambda x: x[-3:])

    # ============================ Composition =====================

    # Product list
    product_composition_list = soup.find_all('div', 'pdp-description-list-item')

    # Composition
    product_composition = [list( filter( None, p.get_text().split('\n') ) ) for p in product_composition_list]

  
    # dataframe
    df_composition = pd.DataFrame(product_composition).T

    # Columns name
    df_composition.columns = df_composition.iloc[0]

    # Filling None/NA values
    df_composition = df_composition.iloc[1:].fillna(method='ffill')

    # The same number of columns (pattern)
    df_composition = pd.concat( [df_pattern, df_composition] )
    
    # Generate Style ID + Color ID
    # All values, but the last three values
    df_composition['style_id'] = df_composition['Art. No.'].apply(lambda x: x[:-3])
    df_composition['color_id'] = df_composition['Art. No.'].apply(lambda x: x[-3:])
    
    # ======================= Merging color + composition ==========================
    data_merge = pd.merge(df_color, df_composition[['style_id', 'Fit', 'Composition', 'More sustainable materials', 'Size']], how='left', on='style_id')

    # ======================= Concatenate ==========================================
    df_final = pd.concat( [df_final, data_merge], axis=0 )

# %%
df_final
# Out:
#             id             color style_id color_id       Fit  \
# 0   1024256002  Light denim blue  1024256      002  Slim fit
# 1   1024256002  Light denim blue  1024256      002  Slim fit
# 2   1024256003  Light denim blue  1024256      003  Slim fit
# 3   1024256003  Light denim blue  1024256      003  Slim fit
# 4   1024256004        Denim blue  1024256      004  Slim fit
# ..         ...               ...      ...      ...       ...
# 7   0985197005   Dark denim blue  0985197      005  Slim fit
# 8   0985197006  Light denim blue  0985197      006  Slim fit
# 9   0985197006  Light denim blue  0985197      006  Slim fit
# 10  0985197007         Dark gray  0985197      007  Slim fit
# 11  0985197007         Dark gray  0985197      007  Slim fit
#
#                                  Composition More sustainable materials  \
# 0   Pocket lining: Polyester 65%, Cotton 35%                        NaN
# 1              Shell: Cotton 99%, Spandex 1%                        NaN
# 2   Pocket lining: Polyester 65%, Cotton 35%                        NaN
# 3              Shell: Cotton 99%, Spandex 1%                        NaN
# 4   Pocket lining: Polyester 65%, Cotton 35%                        NaN
# ..                                       ...                        ...
# 7              Shell: Cotton 98%, Spandex 2%                        NaN
# 8                 Pocket lining: Cotton 100%                        NaN
# 9              Shell: Cotton 98%, Spandex 2%                        NaN
# 10                Pocket lining: Cotton 100%                        NaN
# 11             Shell: Cotton 98%, Spandex 2%                        NaN
#
#                                               Size
# 0   The model is 185cm/6'1" and wears a size 31/32
# 1   The model is 185cm/6'1" and wears a size 31/32
# 2   The model is 185cm/6'1" and wears a size 31/32
# 3   The model is 185cm/6'1" and wears a size 31/32
# 4   The model is 185cm/6'1" and wears a size 31/32
# ..                                             ...
# 7   The model is 189cm/6'2" and wears a size 32/32
# 8   The model is 189cm/6'2" and wears a size 32/32
# 9   The model is 189cm/6'2" and wears a size 32/32
# 10  The model is 189cm/6'2" and wears a size 32/32
# 11  The model is 189cm/6'2" and wears a size 32/32
#
# [457 rows x 8 columns]
